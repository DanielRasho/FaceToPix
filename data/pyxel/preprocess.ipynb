# %%
from PIL import Image
import os
from collections import defaultdict
from pathlib import Path

# %%
def categorize_images_by_size(input_folder):
    # Define size categories (width x height)
    categories = [
        ("< 24x24", 0, 24),
        ("24x24 - 32x32", 24, 32),
        ("32x32 - 64x64", 32, 64),
        ("64x64 - 128x128", 64, 128),
        ("128x128 - 256x256", 128, 256),
        ("256x256 - 512x512", 256, 512),
        ("> 512x512", 512, float('inf'))
    ]
    
    # Track counts and store image details
    category_counts = defaultdict(int)
    category_images = defaultdict(list)
    
    # Supported image formats
    valid_extensions = {'.png', '.jpg', '.jpeg'}
    
    total_images = 0
    
    print("Analyzing images...\n")
    
    # Process each image
    for filename in os.listdir(input_folder):
        file_path = os.path.join(input_folder, filename)
        
        if not os.path.isfile(file_path):
            continue
            
        ext = os.path.splitext(filename)[1].lower()
        if ext not in valid_extensions:
            continue
        
        try:
            img = Image.open(file_path)
            width, height = img.size
            max_dimension = max(width, height)
            
            # Find appropriate category
            for cat_name, min_size, max_size in categories:
                if min_size <= max_dimension < max_size:
                    category_counts[cat_name] += 1
                    category_images[cat_name].append(f"{filename} ({width}x{height})")
                    break
            
            total_images += 1
            
        except Exception as e:
            print(f"✗ Error reading {filename}: {str(e)}")
    
    # Print frequency table
    print("=" * 70)
    print("IMAGE SIZE DISTRIBUTION")
    print("=" * 70)
    print(f"{'Category':<20} {'Count':>10} {'Percentage':>12} {'Bar':>20}")
    print("-" * 70)
    
    for cat_name, min_size, max_size in categories:
        count = category_counts[cat_name]
        percentage = (count / total_images * 100) if total_images > 0 else 0
        
        # Create visual bar
        bar_length = int(percentage / 5)  # Scale: 5% = 1 char
        bar = "█" * bar_length
        
        print(f"{cat_name:<20} {count:>10} {percentage:>11.1f}% {bar:>20}")
    
    print("-" * 70)
    print(f"{'TOTAL':<20} {total_images:>10} {100.0:>11.1f}%")
    print("=" * 70)
    
    # Print detailed breakdown (optional)
    print("\n" + "=" * 70)
    print("DETAILED BREAKDOWN BY CATEGORY")
    print("=" * 70)
    
    for cat_name, min_size, max_size in categories:
        if category_counts[cat_name] > 0:
            print(f"\n{cat_name}: {category_counts[cat_name]} images")
            print("-" * 70)
            for img_info in category_images[cat_name][:10]:  # Show first 10
                print(f"  • {img_info}")
            
            if len(category_images[cat_name]) > 10:
                remaining = len(category_images[cat_name]) - 10
                print(f"  ... and {remaining} more")
    
    print("\n" + "=" * 70)
    
    return category_counts, total_images


# Usage example
input_folder = "./src"

if not os.path.exists(input_folder):
    print(f"Error: Folder '{input_folder}' not found!")
    print("Please update the input_folder path.")
else:
    categorize_images_by_size(input_folder)
# Out:
# Analyzing images...
#
# ======================================================================
# IMAGE SIZE DISTRIBUTION
# ======================================================================
# Category                  Count   Percentage                  Bar
# ----------------------------------------------------------------------
# < 24x24                      91         2.0%
# 24x24 - 32x32                21         0.5%
# 32x32 - 64x64               472        10.1%                   ██
# 64x64 - 128x128            1240        26.6%                █████
# 128x128 - 256x256          1610        34.5%               ██████
# 256x256 - 512x512           884        19.0%                  ███
# > 512x512                   344         7.4%                    █
# ----------------------------------------------------------------------
# TOTAL                      4662       100.0%
# ======================================================================
#
# ======================================================================
# DETAILED BREAKDOWN BY CATEGORY
# ======================================================================
#
# < 24x24: 91 images
# ----------------------------------------------------------------------
#   • 002-lospec-dailies-286456.png (16x16)
#   • fresno-nightcrawler-082838.png (16x15)
#   • green-slime-040105.png (16x16)
#   • lucky-233678.png (16x16)
#   • goldfish-guy-in-a-hoodie-537875.png (16x16)
#   • skull-862408.png (16x16)
#   • daily-fall-368915.png (16x16)
#   • holla-holla-get-gold-coin-843163.png (16x16)
#   • toilet-793217.png (16x16)
#   • half-switch-499510.png (16x16)
#   ... and 81 more
#
# 24x24 - 32x32: 21 images
# ----------------------------------------------------------------------
#   • golem-of-hill-073378.png (29x29)
#   • self-portrait-124163.png (24x24)
#   • eyeless-person-709590.png (16x24)
#   • 9-28-2025-daily-pixel-art-underwater-theme-mana-gem-color-pall-848813.png (23x26)
#   • black-hole-789689.png (29x29)
#   • mask-091927.png (31x31)
#   • underwater-2-937780.png (24x24)
#   • frog-wit-crystals-947430.png (26x26)
#   • lillia-939645.png (28x28)
#   • cultistpng-911223.png (20x28)
#   ... and 11 more
#
# 32x32 - 64x64: 472 images
# ----------------------------------------------------------------------
#   • his-not-so-smart-as-hi-think-he-is-396583.png (32x32)
#   • planet-995488.png (32x32)
#   • trail-of-torment-393029.png (48x48)
#   • amethyst-269828.png (32x32)
#   • pajama-man-146780.png (32x32)
#   • vines-126987.png (32x32)
#   • jones-sprite-050601.png (16x32)
#   • lopunny-worried-498333.png (40x40)
#   • eraser-241599.png (32x32)
#   • mano-galinha-461776.png (38x52)
#   ... and 462 more
#
# 64x64 - 128x128: 1240 images
# ----------------------------------------------------------------------
#   • oh-no-276053.png (96x96)
#   • a-game-du-you-wanna-584037.png (64x64)
#   • starry-night-434230.png (80x55)
#   • the-color-out-of-space-242366.png (64x64)
#   • mountains-630341.png (64x64)
#   • deathacid-027277.png (120x120)
#   • beast-842500.png (64x64)
#   • simon-the-digger-989691.png (64x64)
#   • a-mothers-protection-027755.png (64x64)
#   • pixel-art-freebie-for-matingcall-on-gaiaonline-837764.png (64x64)
#   ... and 1230 more
#
# 128x128 - 256x256: 1610 images
# ----------------------------------------------------------------------
#   • last-ronin-pixelart-fanart-227054.png (180x120)
#   • coming-soon-017725.png (128x160)
#   • bubble-moon-111779.png (128x128)
#   • deidara-988234.png (128x128)
#   • chun-li-360369.png (128x128)
#   • snowy-mountains-276481.png (200x200)
#   • mesa-589863.png (210x120)
#   • substantiation-956675.png (128x128)
#   • windmill-tranquility-765126.png (160x224)
#   • from-orbit-822444.png (200x200)
#   ... and 1600 more
#
# 256x256 - 512x512: 884 images
# ----------------------------------------------------------------------
#   • windows-xp-for-c64-074511.png (320x200)
#   • what-393777.png (320x200)
#   • first-day-of-school-466173.png (166x333)
#   • windy-day-253632.png (392x240)
#   • phantom-blood-8bit-185693.png (256x224)
#   • dreamland-583903.png (297x445)
#   • over-the-bridge-263435.png (256x256)
#   • akane-angele-v2-899778.png (261x296)
#   • x-muffet-132252.png (449x481)
#   • homestreet-snowfall-940366.png (400x400)
#   ... and 874 more
#
# > 512x512: 344 images
# ----------------------------------------------------------------------
#   • 013ans-433589.png (640x688)
#   • 014ans-181630.png (640x688)
#   • one-piece-924661.png (1410x275)
#   • bub-from-bubble-bobble-478363.png (808x679)
#   • spy-platformer-186483.png (576x504)
#   • 022xb-074152.png (640x880)
#   • my-first-pixel-art-576129.png (1083x724)
#   • peacefield-491288.png (441x551)
#   • cloud-867543.png (512x512)
#   • assets-scape-cat-704845.png (1037x371)
#   ... and 334 more
#
# ======================================================================

# %%
def categorize_images_by_aspect_ratio(input_folder):
    # Define aspect ratio categories
    # Format: (name, min_ratio, max_ratio)
    categories = [
        ("Square (1:1)", 0.95, 1.05),           # Nearly square
        ("Slightly Wide (5:4 to 4:3)", 1.05, 1.4),
        ("Wide (16:10 to 16:9)", 1.4, 1.9),
        ("Very Wide (2:1+)", 1.9, float('inf')),
        ("Slightly Tall (4:5 to 3:4)", 0.71, 0.95),
        ("Tall (9:16 to 10:16)", 0.53, 0.71),
        ("Very Tall (1:2+)", 0, 0.53)
    ]
    
    # Track counts and store image details
    category_counts = defaultdict(int)
    category_images = defaultdict(list)
    
    # Supported image formats
    valid_extensions = {'.png', '.jpg', '.jpeg', '.bmp', '.gif'}
    
    total_images = 0
    
    print("Analyzing aspect ratios...\n")
    
    # Process each image
    for filename in os.listdir(input_folder):
        file_path = os.path.join(input_folder, filename)
        
        if not os.path.isfile(file_path):
            continue
            
        ext = os.path.splitext(filename)[1].lower()
        if ext not in valid_extensions:
            continue
        
        try:
            img = Image.open(file_path)
            width, height = img.size
            
            # Calculate aspect ratio (width / height)
            aspect_ratio = width / height if height > 0 else 0
            
            # Find appropriate category
            for cat_name, min_ratio, max_ratio in categories:
                if min_ratio <= aspect_ratio < max_ratio:
                    category_counts[cat_name] += 1
                    category_images[cat_name].append(
                        f"{filename} ({width}x{height}, ratio: {aspect_ratio:.2f})"
                    )
                    break
            
            total_images += 1
            
        except Exception as e:
            print(f"✗ Error reading {filename}: {str(e)}")
    
    # Print frequency table
    print("=" * 75)
    print("IMAGE ASPECT RATIO DISTRIBUTION")
    print("=" * 75)
    print(f"{'Category':<30} {'Count':>10} {'Percentage':>12} {'Bar':>15}")
    print("-" * 75)
    
    for cat_name, min_ratio, max_ratio in categories:
        count = category_counts[cat_name]
        percentage = (count / total_images * 100) if total_images > 0 else 0
        
        # Create visual bar
        bar_length = int(percentage / 5)  # Scale: 5% = 1 char
        bar = "█" * bar_length
        
        print(f"{cat_name:<30} {count:>10} {percentage:>11.1f}% {bar:>15}")
    
    print("-" * 75)
    print(f"{'TOTAL':<30} {total_images:>10} {100.0:>11.1f}%")
    print("=" * 75)
    
    # Print detailed breakdown
    print("\n" + "=" * 75)
    print("DETAILED BREAKDOWN BY CATEGORY")
    print("=" * 75)
    
    for cat_name, min_ratio, max_ratio in categories:
        if category_counts[cat_name] > 0:
            print(f"\n{cat_name}: {category_counts[cat_name]} images")
            print("-" * 75)
            for img_info in category_images[cat_name][:10]:  # Show first 10
                print(f"  • {img_info}")
            
            if len(category_images[cat_name]) > 10:
                remaining = len(category_images[cat_name]) - 10
                print(f"  ... and {remaining} more")
    
    print("\n" + "=" * 75)
    
    # Summary warnings
    print("\n⚠️  ASPECT RATIO WARNINGS:")
    print("-" * 75)
    
    extreme_wide = category_counts["Very Wide (2:1+)"]
    extreme_tall = category_counts["Very Tall (1:2+)"]
    
    if extreme_wide > 0:
        print(f"  • {extreme_wide} images are very wide (ratio > 1.9)")
        print(f"    These may look stretched when converted to square.")
    
    if extreme_tall > 0:
        print(f"  • {extreme_tall} images are very tall (ratio < 0.53)")
        print(f"    These may look stretched when converted to square.")
    
    if extreme_wide == 0 and extreme_tall == 0:
        print(f"  ✓ No extreme aspect ratios detected!")
    
    square_like = category_counts["Square (1:1)"]
    print(f"\n  ✓ {square_like} images are already square or nearly square")
    print("=" * 75)
    
    return category_counts, total_images


# Usage example
input_folder = "./src"

if not os.path.exists(input_folder):
    print(f"Error: Folder '{input_folder}' not found!")
    print("Please update the input_folder path.")
else:
    categorize_images_by_aspect_ratio(input_folder)
# Out:
# Analyzing aspect ratios...
#
# ===========================================================================
# IMAGE ASPECT RATIO DISTRIBUTION
# ===========================================================================
# Category                            Count   Percentage             Bar
# ---------------------------------------------------------------------------
# Square (1:1)                         3014        54.8%      ██████████
# Slightly Wide (5:4 to 4:3)            583        10.6%              ██
# Wide (16:10 to 16:9)                  682        12.4%              ██
# Very Wide (2:1+)                      291         5.3%               █
# Slightly Tall (4:5 to 3:4)            500         9.1%               █
# Tall (9:16 to 10:16)                  332         6.0%               █
# Very Tall (1:2+)                       94         1.7%
# ---------------------------------------------------------------------------
# TOTAL                                5496       100.0%
# ===========================================================================
#
# ===========================================================================
# DETAILED BREAKDOWN BY CATEGORY
# ===========================================================================
#
# Square (1:1): 3014 images
# ---------------------------------------------------------------------------
#   • his-not-so-smart-as-hi-think-he-is-396583.png (32x32, ratio: 1.00)
#   • oh-no-276053.png (96x96, ratio: 1.00)
#   • golem-of-hill-073378.png (29x29, ratio: 1.00)
#   • a-game-du-you-wanna-584037.png (64x64, ratio: 1.00)
#   • the-color-out-of-space-242366.png (64x64, ratio: 1.00)
#   • planet-995488.png (32x32, ratio: 1.00)
#   • mountains-630341.png (64x64, ratio: 1.00)
#   • bubble-moon-111779.png (128x128, ratio: 1.00)
#   • dragon80-731973.gif (72x72, ratio: 1.00)
#   • deidara-988234.png (128x128, ratio: 1.00)
#   ... and 3004 more
#
# Slightly Wide (5:4 to 4:3): 583 images
# ---------------------------------------------------------------------------
#   • mouse-882210.gif (81x74, ratio: 1.09)
#   • phantom-blood-8bit-185693.png (256x224, ratio: 1.14)
#   • bub-from-bubble-bobble-478363.png (808x679, ratio: 1.19)
#   • spy-platformer-186483.png (576x504, ratio: 1.14)
#   • wheat-field-caught-in-the-storm-328074.png (160x120, ratio: 1.33)
#   • lover-058145.png (300x250, ratio: 1.20)
#   • mountainous-nostalgia-837714.png (374x347, ratio: 1.08)
#   • kirbys-adventure-screenshot-redesign-690873.png (256x224, ratio: 1.14)
#   • fresno-nightcrawler-082838.png (16x15, ratio: 1.07)
#   • mars-city-part-4-184136.png (320x240, ratio: 1.33)
#   ... and 573 more
#
# Wide (16:10 to 16:9): 682 images
# ---------------------------------------------------------------------------
#   • windows-xp-for-c64-074511.png (320x200, ratio: 1.60)
#   • what-393777.png (320x200, ratio: 1.60)
#   • starry-night-434230.png (80x55, ratio: 1.45)
#   • last-ronin-pixelart-fanart-227054.png (180x120, ratio: 1.50)
#   • windy-day-253632.png (392x240, ratio: 1.63)
#   • mesa-589863.png (210x120, ratio: 1.75)
#   • fire-emblem-the-blazing-blade-marigold-101242.gif (240x160, ratio: 1.50)
#   • orange-illustration-522122.gif (1920x1080, ratio: 1.78)
#   • sandria-242924.png (320x180, ratio: 1.78)
#   • enchanted-forest-162004.png (320x180, ratio: 1.78)
#   ... and 672 more
#
# Very Wide (2:1+): 291 images
# ---------------------------------------------------------------------------
#   • niche-227510.png (128x64, ratio: 2.00)
#   • one-piece-924661.png (1410x275, ratio: 5.13)
#   • jana-tale-780606.gif (90x39, ratio: 2.31)
#   • north-star-197111.gif (512x256, ratio: 2.00)
#   • swamp-snake-198212.png (128x64, ratio: 2.00)
#   • going-through-a-story-arc-694233.gif (256x128, ratio: 2.00)
#   • assets-scape-cat-704845.png (1037x371, ratio: 2.80)
#   • there-are-rumors-894476.png (128x64, ratio: 2.00)
#   • ohghi984-435610.png (480x142, ratio: 3.38)
#   • logan-roy-from-succession-tv-series-545015.png (288x144, ratio: 2.00)
#   ... and 281 more
#
# Slightly Tall (4:5 to 3:4): 500 images
# ---------------------------------------------------------------------------
#   • flipside-boss-fight-animation-898573.gif (1100x1320, ratio: 0.83)
#   • coming-soon-017725.png (128x160, ratio: 0.80)
#   • 013ans-433589.png (640x688, ratio: 0.93)
#   • windmill-tranquility-765126.png (160x224, ratio: 0.71)
#   • 014ans-181630.png (640x688, ratio: 0.93)
#   • meridias-beacon-861819.png (190x220, ratio: 0.86)
#   • akane-angele-v2-899778.png (261x296, ratio: 0.88)
#   • x-muffet-132252.png (449x481, ratio: 0.93)
#   • 022xb-074152.png (640x880, ratio: 0.73)
#   • bullet-train-fan-art-443564.gif (1640x1820, ratio: 0.90)
#   ... and 490 more
#
# Tall (9:16 to 10:16): 332 images
# ---------------------------------------------------------------------------
#   • dreamland-583903.png (297x445, ratio: 0.67)
#   • american-gothic-1930-by-grant-wood-555877.png (159x226, ratio: 0.70)
#   • 026xb-167305.png (640x960, ratio: 0.67)
#   • server-room-943422.png (54x86, ratio: 0.63)
#   • pillar-889675.png (150x220, ratio: 0.68)
#   • in-the-end-well-all-become-stories-346337.gif (129x192, ratio: 0.67)
#   • fred-055699.png (64x96, ratio: 0.67)
#   • pink-8-bit-462132.png (32x48, ratio: 0.67)
#   • elektrichka-574649.png (150x218, ratio: 0.69)
#   • tree-in-a-pot-763187.png (360x676, ratio: 0.53)
#   ... and 322 more
#
# Very Tall (1:2+): 94 images
# ---------------------------------------------------------------------------
#   • first-day-of-school-466173.png (166x333, ratio: 0.50)
#   • jones-sprite-050601.png (16x32, ratio: 0.50)
#   • keys-of-destiny-483235.png (128x256, ratio: 0.50)
#   • lightning-403054.gif (16x32, ratio: 0.50)
#   • olddoor-390670.png (154x304, ratio: 0.51)
#   • the-light-within-the-rain-299145.png (125x275, ratio: 0.45)
#   • blue-hills-544678.png (64x128, ratio: 0.50)
#   • distant-castle-657539.png (64x128, ratio: 0.50)
#   • direct-794682.png (128x256, ratio: 0.50)
#   • wolfenstein-3d-soldier-203710.png (22x48, ratio: 0.46)
#   ... and 84 more
#
# ===========================================================================
#
# ⚠️  ASPECT RATIO WARNINGS:
# ---------------------------------------------------------------------------
#   • 291 images are very wide (ratio > 1.9)
#     These may look stretched when converted to square.
#   • 94 images are very tall (ratio < 0.53)
#     These may look stretched when converted to square.
#
#   ✓ 3014 images are already square or nearly square
# ===========================================================================

# %%
def process_pixel_art(input_folder, output_folder, target_size=128):
    # Create output folder if it doesn't exist
    Path(output_folder).mkdir(parents=True, exist_ok=True)
    
    # Supported image formats
    valid_extensions = {'.png', '.jpg', '.jpeg', '.bmp', '.gif'}
    
    # Process each image in the input folder
    for filename in os.listdir(input_folder):
        file_path = os.path.join(input_folder, filename)
        
        # Skip if not a file or not a valid image
        if not os.path.isfile(file_path):
            continue
            
        ext = os.path.splitext(filename)[1].lower()
        if ext not in valid_extensions:
            continue
        
        try:
            # Open image
            img = Image.open(file_path)
            
            # Handle transparency: replace with black if PNG has alpha channel
            if ext == '.png' and (img.mode == 'RGBA' or img.mode == 'LA' or 'transparency' in img.info):
                # Create black background
                background = Image.new('RGB', img.size, (0, 0, 0))
                # Convert image to RGBA if needed
                if img.mode != 'RGBA':
                    img = img.convert('RGBA')
                # Composite image over black background
                background.paste(img, mask=img.split()[3])  # Use alpha channel as mask
                img = background
            else:
                # Convert to RGB for consistent color fidelity
                if img.mode != 'RGB':
                    img = img.convert('RGB')
            
            width, height = img.size
            
            # Skip images larger than 512x512
            if width > 512 or height > 512:
                print(f"⊗ Skipped: {filename} ({width}x{height} - exceeds 512x512 limit)")
                continue
            
            # Calculate aspect ratio and skip extreme ratios
            aspect_ratio = width / height if height > 0 else 0
            
            # Skip very wide images (ratio >= 1.9)
            if aspect_ratio >= 1.9:
                print(f"⊗ Skipped: {filename} ({width}x{height}, ratio: {aspect_ratio:.2f} - too wide)")
                continue
            
            # Skip very tall images (ratio <= 0.53)
            if aspect_ratio <= 0.53:
                print(f"⊗ Skipped: {filename} ({width}x{height}, ratio: {aspect_ratio:.2f} - too tall)")
                continue
            
            # Case 1: Image needs to be cropped (larger than target)
            if width > target_size or height > target_size:
                # Step 1: Scale down so the smaller dimension equals target_size
                # This maintains aspect ratio without distortion
                if width < height:
                    # Width is smaller, scale so width = target_size
                    scale_factor = target_size / width
                    new_width = target_size
                    new_height = int(height * scale_factor)
                else:
                    # Height is smaller (or equal), scale so height = target_size
                    scale_factor = target_size / height
                    new_height = target_size
                    new_width = int(width * scale_factor)
                
                # Resize with NEAREST to maintain sharp pixel art edges
                img = img.resize((new_width, new_height), Image.NEAREST)
                
                # Step 2: Crop the larger dimension from center if still > target_size
                width, height = img.size
                
                if width > target_size or height > target_size:
                    left = (width - target_size) // 2
                    top = (height - target_size) // 2
                    right = left + target_size
                    bottom = top + target_size
                    
                    img = img.crop((left, top, right, bottom))
            
            # Case 2: Image needs to be scaled up (smaller than target)
            elif width < target_size or height < target_size:
                # Use NEAREST neighbor to maintain sharp pixel art edges
                img = img.resize((target_size, target_size), Image.NEAREST)
            
            # Case 3: Image is already the target size
            # (no action needed)
            
            # Save processed image
            output_path = os.path.join(output_folder, filename)
            
            # Save as PNG to preserve color fidelity (no compression artifacts)
            if ext != '.png':
                output_path = os.path.splitext(output_path)[0] + '.png'
            
            img.save(output_path, 'PNG', optimize=False)
            print(f"✓ Processed: {filename} ({width}x{height} → {target_size}x{target_size})")
            
        except Exception as e:
            print(f"✗ Error processing {filename}: {str(e)}")

input_folder = "./src"
output_folder = "./final"

process_pixel_art(input_folder, output_folder, target_size=64)
print("\nProcessing complete!")
# Out:
# ✓ Processed: his-not-so-smart-as-hi-think-he-is-396583.png (32x32 → 64x64)
# ⊗ Skipped: flipside-boss-fight-animation-898573.gif (1100x1320 - exceeds 512x512 limit)
# ✓ Processed: oh-no-276053.png (64x64 → 64x64)
# ✓ Processed: golem-of-hill-073378.png (29x29 → 64x64)
# ✓ Processed: windows-xp-for-c64-074511.png (102x64 → 64x64)
# ✓ Processed: what-393777.png (102x64 → 64x64)
# ✓ Processed: a-game-du-you-wanna-584037.png (64x64 → 64x64)
# ✓ Processed: starry-night-434230.png (93x64 → 64x64)
# ✓ Processed: last-ronin-pixelart-fanart-227054.png (96x64 → 64x64)
# ✓ Processed: coming-soon-017725.png (64x80 → 64x64)
# ✓ Processed: the-color-out-of-space-242366.png (64x64 → 64x64)
# ⊗ Skipped: first-day-of-school-466173.png (166x333, ratio: 0.50 - too tall)
# ✓ Processed: planet-995488.png (32x32 → 64x64)
# ✓ Processed: mountains-630341.png (64x64 → 64x64)
# ✓ Processed: bubble-moon-111779.png (64x64 → 64x64)
# ✓ Processed: dragon80-731973.gif (64x64 → 64x64)
# ✓ Processed: deidara-988234.png (64x64 → 64x64)
# ✓ Processed: windy-day-253632.png (104x64 → 64x64)
# ⊗ Skipped: 013ans-433589.png (640x688 - exceeds 512x512 limit)
# ✓ Processed: chun-li-360369.png (64x64 → 64x64)
# ✓ Processed: deathacid-027277.png (64x64 → 64x64)
# ✓ Processed: snowy-mountains-276481.png (64x64 → 64x64)
# ✓ Processed: beast-842500.png (64x64 → 64x64)
# ✓ Processed: mesa-589863.png (112x64 → 64x64)
# ✓ Processed: trail-of-torment-393029.png (48x48 → 64x64)
# ✓ Processed: mouse-882210.gif (70x64 → 64x64)
# ✓ Processed: through-the-keyhole-247420.gif (64x64 → 64x64)
# ✓ Processed: 002-lospec-dailies-286456.png (16x16 → 64x64)
# ✓ Processed: the-cave-785069.gif (64x64 → 64x64)
# ✓ Processed: phantom-blood-8bit-185693.png (73x64 → 64x64)
# ✓ Processed: amethyst-269828.png (32x32 → 64x64)
# ✓ Processed: dreamland-583903.png (64x95 → 64x64)
# ✓ Processed: cherry-blossom-764237.gif (64x64 → 64x64)
# ✓ Processed: nitori-kawashiro-365194.gif (64x64 → 64x64)
# ✓ Processed: substantiation-956675.png (64x64 → 64x64)
# ✓ Processed: simon-the-digger-989691.png (64x64 → 64x64)
# ✓ Processed: dragon-009355.gif (64x64 → 64x64)
# ✓ Processed: windmill-tranquility-765126.png (64x89 → 64x64)
# ✓ Processed: from-orbit-822444.png (64x64 → 64x64)
# ✓ Processed: night-window-628578.png (64x64 → 64x64)
# ✓ Processed: a-mothers-protection-027755.png (64x64 → 64x64)
# ⊗ Skipped: 014ans-181630.png (640x688 - exceeds 512x512 limit)
# ⊗ Skipped: niche-227510.png (128x64, ratio: 2.00 - too wide)
# ✓ Processed: kilrogg-deadeye-009845.png (64x64 → 64x64)
# ⊗ Skipped: one-piece-924661.png (1410x275 - exceeds 512x512 limit)
# ✓ Processed: pixel-art-freebie-for-matingcall-on-gaiaonline-837764.png (64x64 → 64x64)
# ⊗ Skipped: bub-from-bubble-bobble-478363.png (808x679 - exceeds 512x512 limit)
# ✓ Processed: the-orb-521010.png (64x64 → 64x64)
# ✓ Processed: over-the-bridge-263435.png (64x64 → 64x64)
# ✓ Processed: pajama-man-146780.png (32x32 → 64x64)
# ⊗ Skipped: jana-tale-780606.gif (90x39, ratio: 2.31 - too wide)
# ✓ Processed: fire-emblem-the-blazing-blade-marigold-101242.gif (96x64 → 64x64)
# ✓ Processed: meridias-beacon-861819.png (64x74 → 64x64)
# ✓ Processed: vines-126987.png (32x32 → 64x64)
# ⊗ Skipped: north-star-197111.gif (512x256, ratio: 2.00 - too wide)
# ✓ Processed: divagation-167236.png (64x64 → 64x64)
# ✓ Processed: akane-angele-v2-899778.png (64x72 → 64x64)
# ✓ Processed: smoke-and-spires-346577.png (64x64 → 64x64)
# ✓ Processed: masks-886855.png (64x64 → 64x64)
# ✓ Processed: x-muffet-132252.png (64x68 → 64x64)
# ⊗ Skipped: swamp-snake-198212.png (128x64, ratio: 2.00 - too wide)
# ⊗ Skipped: heart-3-608538.gif (992x992 - exceeds 512x512 limit)
# ⊗ Skipped: orange-illustration-522122.gif (1920x1080 - exceeds 512x512 limit)
# ⊗ Skipped: spy-platformer-186483.png (576x504 - exceeds 512x512 limit)
# ✓ Processed: aoi-oc-196334.png (64x64 → 64x64)
# ⊗ Skipped: jones-sprite-050601.png (16x32, ratio: 0.50 - too tall)
# ✓ Processed: randy-qubit-pix-it-in-picocad-638896.gif (64x64 → 64x64)
# ✓ Processed: mobile-legends-sprite-001-miya-354142.png (64x64 → 64x64)
# ⊗ Skipped: 022xb-074152.png (640x880 - exceeds 512x512 limit)
# ✓ Processed: neon-werewhale-432379.png (64x64 → 64x64)
# ✓ Processed: homestreet-snowfall-940366.png (64x64 → 64x64)
# ✓ Processed: lopunny-worried-498333.png (40x40 → 64x64)
# ✓ Processed: sandria-242924.png (113x64 → 64x64)
# ✓ Processed: goku-goes-super-sayian-554524.png (64x64 → 64x64)
# ✓ Processed: widowmakers-sniper-from-overwatch-658221.gif (64x64 → 64x64)
# ✓ Processed: cheese-of-toast-and-egg-the-most-223892.png (64x64 → 64x64)
# ✓ Processed: smoke-089636.gif (64x64 → 64x64)
# ✓ Processed: succubus-163781.png (64x64 → 64x64)
# ✓ Processed: wheat-field-caught-in-the-storm-328074.png (85x64 → 64x64)
# ✓ Processed: mobile-legends-sprtie-034estes-174062.png (64x64 → 64x64)
# ✓ Processed: fishbowl-eye-city-507721.gif (64x64 → 64x64)
# ✓ Processed: toyosatomimi-no-miko-781789.gif (64x64 → 64x64)
# ✓ Processed: smile-578962.png (64x64 → 64x64)
# ⊗ Skipped: bullet-train-fan-art-443564.gif (1640x1820 - exceeds 512x512 limit)
# ✓ Processed: astianax-model-idel-animation-number-1-865772.gif (32x32 → 64x64)
# ✓ Processed: the-eyeball-room-880532.png (64x64 → 64x64)
# ✓ Processed: gnome-magic-541185.png (64x64 → 64x64)
# ✓ Processed: enot-idle-145938.gif (32x32 → 64x64)
# ✓ Processed: to-all-of-you-in-2016-680324.png (64x75 → 64x64)
# ✓ Processed: enchanted-forest-162004.png (113x64 → 64x64)
# ✓ Processed: eraser-241599.png (32x32 → 64x64)
# ✓ Processed: dear-creator-hatsune-miku-430192.png (64x64 → 64x64)
# ⊗ Skipped: going-through-a-story-arc-694233.gif (256x128, ratio: 2.00 - too wide)
# ✓ Processed: tin-robot-wants-a-hug-361240.png (64x64 → 64x64)
# ⊗ Skipped: my-first-pixel-art-576129.png (1083x724 - exceeds 512x512 limit)
# ✓ Processed: lover-058145.png (76x64 → 64x64)
# ✓ Processed: profile-picture-autoportrait-248587.png (64x64 → 64x64)
# ⊗ Skipped: peacefield-491288.png (441x551 - exceeds 512x512 limit)
# ✓ Processed: mano-galinha-461776.png (38x52 → 64x64)
# ✓ Processed: mountainous-nostalgia-837714.png (68x64 → 64x64)
# ✓ Processed: princess-in-spotlight-893805.png (64x64 → 64x64)
# ✓ Processed: american-gothic-1930-by-grant-wood-555877.png (64x90 → 64x64)
# ✓ Processed: cloud-867543.png (64x64 → 64x64)
# ⊗ Skipped: keys-of-destiny-483235.png (128x256, ratio: 0.50 - too tall)
# ⊗ Skipped: assets-scape-cat-704845.png (1037x371 - exceeds 512x512 limit)
# ✓ Processed: mobile-legends-sprite-029-ruby-909387.png (64x64 → 64x64)
# ⊗ Skipped: there-are-rumors-894476.png (128x64, ratio: 2.00 - too wide)
# ✓ Processed: alleyway-trash-879199.png (96x64 → 64x64)
# ✓ Processed: in-space-no-one-can-hear-you-screams-238952.png (64x83 → 64x64)
# ✓ Processed: awaken-791928.png (64x64 → 64x64)
# ⊗ Skipped: lightning-403054.gif (16x32, ratio: 0.50 - too tall)
# ⊗ Skipped: 026xb-167305.png (640x960 - exceeds 512x512 limit)
# ✓ Processed: kirbys-adventure-screenshot-redesign-690873.png (73x64 → 64x64)
# ✓ Processed: troupe-master-grimmsmol-ver-355196.png (64x64 → 64x64)
# ✓ Processed: fresno-nightcrawler-082838.png (16x15 → 64x64)
# ✓ Processed: pelipper-first-pixel-art-945861.png (32x32 → 64x64)
# ✓ Processed: self-portrait-872258.png (64x85 → 64x64)
# ✓ Processed: server-room-943422.png (64x101 → 64x64)
# ✓ Processed: mars-city-part-4-184136.png (85x64 → 64x64)
# ✓ Processed: pillar-889675.png (64x93 → 64x64)
# ✓ Processed: gogmazios-disaster-356142.png (64x64 → 64x64)
# ⊗ Skipped: olddoor-390670.png (154x304, ratio: 0.51 - too tall)
# ✓ Processed: ruins-in-field-304192.png (64x64 → 64x64)
# ✓ Processed: rpg-mockup-693072.png (85x64 → 64x64)
# ✓ Processed: mystic-valley-321965.png (92x64 → 64x64)
# ✓ Processed: remi-532803.gif (89x64 → 64x64)
# ✓ Processed: piccolo-305346.gif (64x64 → 64x64)
# ✓ Processed: grim-343734.png (64x64 → 64x64)
# ✓ Processed: apex-gamerpic-388723.png (64x64 → 64x64)
# ✓ Processed: xp-pen-case-628457.png (64x64 → 64x64)
# ✓ Processed: dark-knight-648383.gif (48x48 → 64x64)
# ✓ Processed: the-night-forest-107459.gif (64x64 → 64x64)
# ✓ Processed: reaver-826883.png (64x64 → 64x64)
# ✓ Processed: house-2-commission-2-4-217046.png (113x64 → 64x64)
# ✓ Processed: a-light-for-who-106121.png (87x64 → 64x64)
# ✓ Processed: athina-103153.png (93x64 → 64x64)
# ✓ Processed: limited-time-offer-656476.png (64x64 → 64x64)
# ✓ Processed: alchemical-assortment-233180.png (64x64 → 64x64)
# ✓ Processed: kyoko-pfp-blessing-palette-896516.png (48x48 → 64x64)
# ✓ Processed: tree-993937.png (32x32 → 64x64)
# ✓ Processed: mother-120685.png (64x64 → 64x64)
# ✓ Processed: office-sheepgirl-982533.gif (64x89 → 64x64)
# ✓ Processed: research-daily-238123.png (64x64 → 64x64)
# ✓ Processed: zombie-suvivor-dx-006640.png (71x64 → 64x64)
# ✓ Processed: ramen-shop-983475.png (113x64 → 64x64)
# ✓ Processed: self-potrait-096309.png (64x85 → 64x64)
# ✓ Processed: pumpkin-bounce-277257.gif (64x64 → 64x64)
# ⊗ Skipped: neon-darkness-894908.png (666x666 - exceeds 512x512 limit)
# ✓ Processed: in-the-end-well-all-become-stories-346337.gif (64x95 → 64x64)
# ✓ Processed: happy-tau-day-2024-924093.png (64x64 → 64x64)
# ✓ Processed: mr-broccolo-746533.png (64x64 → 64x64)
# ✓ Processed: weve-got-to-have-money-856394.png (64x64 → 64x64)
# ✓ Processed: cliffside-walk-monet-study-323736.png (80x64 → 64x64)
# ✓ Processed: oscar-knight-of-astora-386314.png (64x64 → 64x64)
# ✓ Processed: lost-in-matrix-476064.gif (64x64 → 64x64)
# ✓ Processed: she-slept-among-the-pines-144416.png (64x64 → 64x64)
# ✓ Processed: deception-742674.png (64x64 → 64x64)
# ✓ Processed: wildflowers-1-6-249385.png (96x64 → 64x64)
# ⊗ Skipped: ohghi984-435610.png (480x142, ratio: 3.38 - too wide)
# ✓ Processed: first-attempt-at-a-tree-081406.png (64x64 → 64x64)
# ✓ Processed: character-expression-practice-48px-edition-662900.png (64x64 → 64x64)
# ✓ Processed: miku-in-the-wings-of-vi-artstyle-328354.png (64x64 → 64x64)
# ✓ Processed: hirai-idle-311726.gif (64x64 → 64x64)
# ✓ Processed: 25-de-abril-192123.png (64x64 → 64x64)
# ✓ Processed: corpse-flower-dragon-inspired-by-a-corpse-flower-my-teacher-had-320455.png (64x64 → 64x64)
# ✓ Processed: skeleton-king-017755.png (64x64 → 64x64)
# ✓ Processed: van-trip-630251.png (64x68 → 64x64)
# ✓ Processed: father-and-son-bonding-018624.png (64x64 → 64x64)
# ✓ Processed: dead-end-862848.png (64x64 → 64x64)
# ✓ Processed: tree-thingy-idk-830062.png (64x64 → 64x64)
# ✓ Processed: daily-tag-riot-442756.png (106x64 → 64x64)
# ⊗ Skipped: social-ette-hapiness-to-scale-971281.png (1280x720 - exceeds 512x512 limit)
# ✓ Processed: inspection-791741.png (64x64 → 64x64)
# ⊗ Skipped: maki-rolls-197604.png (1554x1110 - exceeds 512x512 limit)
# ✓ Processed: toucan-633520.png (64x64 → 64x64)
# ✓ Processed: fred-055699.png (64x96 → 64x64)
# ✓ Processed: throw-this-into-the-sun-its-ugly-088173.gif (64x64 → 64x64)
# ✓ Processed: 6-color-tree-863614.png (64x64 → 64x64)
# ⊗ Skipped: good-morning-captain-131673.png (1920x1080 - exceeds 512x512 limit)
# ✓ Processed: when-its-early-in-the-morning-dance-764426.png (87x64 → 64x64)
# ✓ Processed: harbinger-980735.png (64x64 → 64x64)
# ✓ Processed: pink-8-bit-462132.png (32x48 → 64x64)
# ✓ Processed: jones-bones-442663.png (64x64 → 64x64)
# ✓ Processed: iglu-minimalist-889563.png (71x64 → 64x64)
# ✓ Processed: luna-dating-sim-portrait-234106.png (64x64 → 64x64)
# ✓ Processed: crow-691048.png (78x64 → 64x64)
# ✓ Processed: me-on-the-moon-981065.png (71x64 → 64x64)
# ✓ Processed: booted-eagle-813312.png (64x64 → 64x64)
# ✓ Processed: elektrichka-574649.png (64x93 → 64x64)
# ✓ Processed: city-977930.png (71x64 → 64x64)
# ✓ Processed: castle-logo-169963.png (64x64 → 64x64)
# ✓ Processed: dinner-825227.png (32x32 → 64x64)
# ✓ Processed: house-upon-a-hill-690453.png (74x64 → 64x64)
# ✓ Processed: kitten-paw-482970.png (32x32 → 64x64)
# ✓ Processed: eyeball-664569.gif (64x64 → 64x64)
# ⊗ Skipped: nosferatu-746146.gif (1280x1280 - exceeds 512x512 limit)
# ✓ Processed: wolf-087646.png (64x64 → 64x64)
# ⊗ Skipped: this-is-a-long-drive-for-someone-with-nothing-to-think-aboutv2-789934.png (1920x1080 - exceeds 512x512 limit)
# ✓ Processed: pixel-portraits-of-my-cats-first-pixel-art-923357.png (48x48 → 64x64)
# ✓ Processed: witcher-558280.png (48x64 → 64x64)
# ⊗ Skipped: the-light-within-the-rain-299145.png (125x275, ratio: 0.45 - too tall)
# ✓ Processed: clair-obscur-450530.png (64x64 → 64x64)
# ✓ Processed: rice-ball-my-man-220595.png (32x32 → 64x64)
# ✓ Processed: astarion-from-baldurs-gate-3-647574.png (64x71 → 64x64)
# ✓ Processed: hollow-knight-poster-484060.png (64x85 → 64x64)
# ✓ Processed: removable-head-033211.png (64x64 → 64x64)
# ⊗ Skipped: tree-in-a-pot-763187.png (360x676 - exceeds 512x512 limit)
# ⊗ Skipped: logan-roy-from-succession-tv-series-545015.png (288x144, ratio: 2.00 - too wide)
# ✓ Processed: ultramarine-226462.png (64x64 → 64x64)
# ✓ Processed: peach-nes-redraw-420479.gif (64x64 → 64x64)
# ✓ Processed: duchess-464899.png (64x64 → 64x64)
# ✓ Processed: juice-box-929351.png (64x64 → 64x64)
# ✓ Processed: riolu-199928.png (45x50 → 64x64)
# ⊗ Skipped: crime-against-italy-997311.png (128x64, ratio: 2.00 - too wide)
# ✓ Processed: veil-011806.png (64x64 → 64x64)
# ✓ Processed: roland-sp-404sx-x4-839870.png (64x64 → 64x64)
# ✓ Processed: head-for-lospec-dailies-8-july-24-111062.png (64x64 → 64x64)
# ✓ Processed: epic-the-musical-the-vengance-saga-495208.png (64x64 → 64x64)
# ✓ Processed: tumbleweed-946034.gif (64x64 → 64x64)
# ✓ Processed: character-garras-de-grifo-812984.gif (64x64 → 64x64)
# ✓ Processed: takom-pixel-art-commission-881349.gif (64x64 → 64x64)
# ✓ Processed: noelle-deltarune-015064.gif (64x64 → 64x64)
# ✓ Processed: nuka-berry-689192.png (64x74 → 64x64)
# ✓ Processed: quick-save-550496.png (64x64 → 64x64)
# ✓ Processed: just-a-funny-lil-guy-behind-that-pop-up-721452.png (64x64 → 64x64)
# ✓ Processed: totally-not-genderbent-versions-of-popular-bear-and-bird-824226.png (64x80 → 64x64)
# ✓ Processed: caroline-from-tormented-souls-32x32-593202.png (64x64 → 64x64)
# ✓ Processed: booo-576984.png (96x64 → 64x64)
# ✓ Processed: street-sign-863992.png (64x99 → 64x64)
# ✓ Processed: pixle-kingdom-569596.png (32x32 → 64x64)
# ✓ Processed: fungi-mon-239121.png (71x64 → 64x64)
# ✓ Processed: brimstone-wick-622586.png (64x64 → 64x64)
# ⊗ Skipped: water-animation-01-891737.gif (565x670 - exceeds 512x512 limit)
# ✓ Processed: wilhelm-von-clausewitz-halcyon-hisuimaru-aka-clause-858901.png (88x64 → 64x64)
# ✓ Processed: moth-869533.png (64x64 → 64x64)
# ✓ Processed: mystery-crystal-771356.png (64x64 → 64x64)
# ✓ Processed: a-fone-a-girls-fone-775799.png (64x64 → 64x64)
# ✓ Processed: beguile-228493.png (64x64 → 64x64)
# ✓ Processed: hp-potion-probably-896581.png (64x64 → 64x64)
# ✓ Processed: resonance-045462.png (64x64 → 64x64)
# ✓ Processed: captain-little-025525.png (75x64 → 64x64)
# ⊗ Skipped: cyan-lizard-553595.png (128x64, ratio: 2.00 - too wide)
# ✓ Processed: chocoball-586428.png (68x64 → 64x64)
# ✓ Processed: hand-study-209365.png (64x64 → 64x64)
# ✓ Processed: gameboy-advance-sp-972996.gif (64x64 → 64x64)
# ✓ Processed: grengi-666223.png (40x40 → 64x64)
# ⊗ Skipped: summer-days-424867.png (256x128, ratio: 2.00 - too wide)
# ✓ Processed: osci-649161.gif (16x16 → 64x64)
# ⊗ Skipped: phone-019670.png (1080x1080 - exceeds 512x512 limit)
# ⊗ Skipped: low-poly-3d-character-model-maia-712929.gif (1920x1080 - exceeds 512x512 limit)
# ✓ Processed: dead-pan-096610.png (64x64 → 64x64)
# ✓ Processed: midnight-walker-730023.png (73x64 → 64x64)
# ✓ Processed: keine-kamishirasawa-301497.gif (64x64 → 64x64)
# ✓ Processed: clock-898834.png (64x64 → 64x64)
# ✓ Processed: ephesian-432-062583.gif (102x64 → 64x64)
# ⊗ Skipped: a-rock-boi-i-made-481311.png (550x550 - exceeds 512x512 limit)
# ⊗ Skipped: blue-hills-544678.png (64x128, ratio: 0.50 - too tall)
# ✓ Processed: minecraft-mini-797536.png (64x64 → 64x64)
# ✓ Processed: fueki-haru-791532.png (83x64 → 64x64)
# ✓ Processed: game-over-kumamori-freya-058208.gif (112x64 → 64x64)
# ⊗ Skipped: bitter-realms-dungeon-tileset-banner-157637.png (240x100, ratio: 2.40 - too wide)
# ⊗ Skipped: tar-104672.png (128x64, ratio: 2.00 - too wide)
# ✓ Processed: visitors-976777.gif (112x64 → 64x64)
# ✓ Processed: blue-rose-276989.png (64x64 → 64x64)
# ✓ Processed: shes-a-star-828342.png (64x64 → 64x64)
# ⊗ Skipped: fanart-for-strawberry-classroom-019423.png (1088x1120 - exceeds 512x512 limit)
# ✓ Processed: candy-mountains-988863.png (85x64 → 64x64)
# ✓ Processed: arcade-196444.gif (64x64 → 64x64)
# ✓ Processed: pixelated-modeus-420450.png (64x80 → 64x64)
# ⊗ Skipped: smb-mario-and-luigi-sprite-for-master-system-401914.gif (320x112, ratio: 2.86 - too wide)
# ✓ Processed: elven-carrots-686072.png (64x64 → 64x64)
# ⊗ Skipped: a-world-without-meteorites-676384.gif (1440x960 - exceeds 512x512 limit)
# ⊗ Skipped: bluehill-650059.png (128x64, ratio: 2.00 - too wide)
# ⊗ Skipped: ppsh-013471.png (192x64, ratio: 3.00 - too wide)
# ✓ Processed: mobile-legends-sprite-57-valir-052139.png (64x64 → 64x64)
# ✓ Processed: the-cat-that-crosses-the-sky-116780.png (64x78 → 64x64)
# ✓ Processed: ascii-pc-799313.png (54x50 → 64x64)
# ✓ Processed: air-869010.png (64x64 → 64x64)
# ✓ Processed: green-slime-040105.png (16x16 → 64x64)
# ✓ Processed: madame-unnamed-775591.png (64x64 → 64x64)
# ✓ Processed: pyramid-head-i-love-u-so-752872.png (64x64 → 64x64)
# ✓ Processed: paper-of-ideas-987351.png (64x64 → 64x64)
# ✓ Processed: skeletons-using-blood-crow-palette-987178.png (64x64 → 64x64)
# ✓ Processed: yoga-scarecrow-691691.png (64x64 → 64x64)
# ✓ Processed: disintegration-291021.png (65x64 → 64x64)
# ✓ Processed: coud-genie-333990.gif (64x87 → 64x64)
# ⊗ Skipped: distant-castle-657539.png (64x128, ratio: 0.50 - too tall)
# ✓ Processed: a-desert-its-dry-287095.png (113x64 → 64x64)
# ✓ Processed: strong-feelings-261201.png (64x96 → 64x64)
# ✓ Processed: unicorn-man-021989.png (32x32 → 64x64)
# ✓ Processed: alittleperspective-collab-entry-62px-version-329962.png (62x62 → 64x64)
# ⊗ Skipped: any-name-981186.png (128x64, ratio: 2.00 - too wide)
# ✓ Processed: mountain-lake-241868.png (73x64 → 64x64)
# ✓ Processed: rooftop-view-463363.png (113x64 → 64x64)
# ✓ Processed: rolling-penguin-for-nes-526275.gif (32x32 → 64x64)
# ✓ Processed: please-stay-with-me-745691.png (64x64 → 64x64)
# ✓ Processed: karlachs-eyes-884770.png (64x68 → 64x64)
# ✓ Processed: broken-crystal-938641.png (64x64 → 64x64)
# ✓ Processed: holy-island-259897.png (64x90 → 64x64)
# ✓ Processed: pumpkin-love-323209.png (64x64 → 64x64)
# ✓ Processed: magic-land-card-swamp-477417.gif (48x64 → 64x64)
# ⊗ Skipped: bulbasaur-256528.png (128x24, ratio: 5.33 - too wide)
# ✓ Processed: yellow-sun-318780.gif (64x96 → 64x64)
# ✓ Processed: tepui-spinetail-416401.png (64x85 → 64x64)
# ✓ Processed: icy-moon-282782.png (68x64 → 64x64)
# ✓ Processed: red-bones-195181.png (64x64 → 64x64)
# ✓ Processed: juggerknight-446207.png (64x96 → 64x64)
# ✓ Processed: rainbow-chase-191545.png (64x76 → 64x64)
# ✓ Processed: gameboy-wars-418689.png (71x64 → 64x64)
# ✓ Processed: kotuxi-196717.gif (89x64 → 64x64)
# ✓ Processed: purpl-ches-792555.png (36x28 → 64x64)
# ✓ Processed: google-maps-landscape-054238.png (113x64 → 64x64)
# ✓ Processed: pixel-daily-wilderness-800430.png (113x64 → 64x64)
# ✓ Processed: tetoris-788974.gif (64x64 → 64x64)
# ✓ Processed: the-weighing-of-the-heart-846953.png (54x54 → 64x64)
# ✓ Processed: grim-365585.png (64x64 → 64x64)
# ✓ Processed: lucky-233678.png (16x16 → 64x64)
# ✓ Processed: aibo-hirana-524161.png (64x64 → 64x64)
# ⊗ Skipped: jonk-16-ortho-study-887124.png (576x576 - exceeds 512x512 limit)
# ⊗ Skipped: beach-003167.png (553x311 - exceeds 512x512 limit)
# ✓ Processed: grey-cap-798275.png (32x32 → 64x64)
# ✓ Processed: winter-forest-mockup-010533.png (68x64 → 64x64)
# ✓ Processed: moai-261288.png (64x64 → 64x64)
# ✓ Processed: the-man-and-the-skeleton-772747.png (64x64 → 64x64)
# ⊗ Skipped: lightning-mesa-878819.png (1920x1080 - exceeds 512x512 limit)
# ✓ Processed: the-last-operator-170924.png (64x94 → 64x64)
# ✓ Processed: priest-lake-707120.png (108x64 → 64x64)
# ✓ Processed: woag-420197.png (64x64 → 64x64)
# ⊗ Skipped: plastic-man-needs-to-regroup-the-league-667371.png (232x60, ratio: 3.87 - too wide)
# ✓ Processed: phantasm-1979-tribute-002886.gif (64x76 → 64x64)
# ✓ Processed: metal-hear-862544.png (64x64 → 64x64)
# ✓ Processed: shooting-wound-685632.png (64x64 → 64x64)
# ✓ Processed: milk-400143.png (64x93 → 64x64)
# ✓ Processed: deku-and-zora-link-148283.png (64x64 → 64x64)
# ✓ Processed: fps-demake-from-ps2-to-game-boy-873318.png (71x64 → 64x64)
# ✓ Processed: little-rabbit-its-a-small-habit-370735.png (40x40 → 64x64)
# ✓ Processed: octopus-086221.png (64x64 → 64x64)
# ⊗ Skipped: imaginary-particle-341867.png (480x240, ratio: 2.00 - too wide)
# ✓ Processed: pillars-181819.png (82x64 → 64x64)
# ✓ Processed: its-mac-tonight-706001.png (64x64 → 64x64)
# ✓ Processed: alien-attack-444796.png (64x95 → 64x64)
# ✓ Processed: fox-in-the-woods-970120.png (40x40 → 64x64)
# ✓ Processed: 32x32-px-zero-suit-samus-608052.png (64x64 → 64x64)
# ✓ Processed: character-idle-animation-922216.gif (64x64 → 64x64)
# ✓ Processed: animal-crossing-villager-105175.png (64x64 → 64x64)
# ✓ Processed: candela-the-wax-spirit-228687.png (64x64 → 64x64)
# ⊗ Skipped: forest-background-540481.png (500x240, ratio: 2.08 - too wide)
# ✓ Processed: archerrightanimation-095210.gif (16x16 → 64x64)
# ✓ Processed: captain-jack-sparrowwait-025033.png (64x64 → 64x64)
# ✓ Processed: goldfish-guy-in-a-hoodie-537875.png (16x16 → 64x64)
# ✓ Processed: the-substance-865793.png (84x64 → 64x64)
# ✓ Processed: coraline-16x16-gb-455026.png (64x64 → 64x64)
# ✓ Processed: jimmy-pupper-245826.gif (64x64 → 64x64)
# ⊗ Skipped: 017xb-974620.png (640x960 - exceeds 512x512 limit)
# ✓ Processed: eyegor-838009.png (64x80 → 64x64)
# ✓ Processed: items-1-173742.png (64x64 → 64x64)
# ✓ Processed: kuro-sawada-portrait-436656.gif (64x64 → 64x64)
# ⊗ Skipped: animated-short-gun-682894.gif (800x512 - exceeds 512x512 limit)
# ✓ Processed: juice-box-re-color-276325.png (64x64 → 64x64)
# ✓ Processed: squirtle-stickeer-sheet-519943.png (64x64 → 64x64)
# ✓ Processed: secretary-bird-267587.png (85x64 → 64x64)
# ⊗ Skipped: mountain-of-fate-659023.png (128x64, ratio: 2.00 - too wide)
# ✓ Processed: nueva-plantilla-de-personaje-2d-idle-250562.gif (64x64 → 64x64)
# ✓ Processed: gif-lost-in-thoughts-aubrey-omori-report-abuse-612604.gif (64x64 → 64x64)
# ✓ Processed: osea-osira-950282.png (64x64 → 64x64)
# ✓ Processed: little-owl-945625.gif (40x60 → 64x64)
# ✓ Processed: sky-372086.png (64x107 → 64x64)
# ✓ Processed: late-lake-daily-560552.png (64x64 → 64x64)
# ✓ Processed: good-night-397528.png (113x64 → 64x64)
# ✓ Processed: shady-013753.png (91x64 → 64x64)
# ✓ Processed: rogue-735998.png (64x64 → 64x64)
# ✓ Processed: lospec-jam-3-art-submission-738128.png (113x64 → 64x64)
# ⊗ Skipped: purgatory-room-ix-771194.gif (1200x840 - exceeds 512x512 limit)
# ✓ Processed: exemption-103942.png (64x64 → 64x64)
# ✓ Processed: pizza-daily-986910.png (64x64 → 64x64)
# ✓ Processed: chief-duck-550465.png (64x64 → 64x64)
# ✓ Processed: alice-in-cometland-492503.gif (64x64 → 64x64)
# ✓ Processed: contaminate-639206.png (92x64 → 64x64)
# ✓ Processed: as-macas-449960.png (44x32 → 64x64)
# ✓ Processed: a-moth-named-isabela-464918.png (64x64 → 64x64)
# ✓ Processed: loyal-frog-wizard-205887.png (45x45 → 64x64)
# ✓ Processed: dystopia-107972.png (74x64 → 64x64)
# ✓ Processed: incentive-690325.png (64x64 → 64x64)
# ✓ Processed: mountains-942419.png (96x64 → 64x64)
# ✓ Processed: tired-slime-203797.gif (32x32 → 64x64)
# ✓ Processed: shore-study-328108.png (64x64 → 64x64)
# ✓ Processed: autumn-road-826400.png (82x64 → 64x64)
# ✓ Processed: computer-487659.gif (72x64 → 64x64)
# ✓ Processed: mobile-legends-sprite-037-lapu-lapu-663619.png (64x64 → 64x64)
# ✓ Processed: super-cs-first-boss-540639.gif (64x64 → 64x64)
# ✓ Processed: my-first-daily-059669.png (32x32 → 64x64)
# ✓ Processed: skull-862408.png (16x16 → 64x64)
# ✓ Processed: two-small-suns-812578.png (64x64 → 64x64)
# ✓ Processed: my-take-on-voltorb-688138.png (64x64 → 64x64)
# ✓ Processed: the-glasses-of-myth-605692.png (64x64 → 64x64)
# ✓ Processed: winter-in-moonlight-944573.png (32x32 → 64x64)
# ✓ Processed: power-line-609248.png (102x64 → 64x64)
# ✓ Processed: bad-apple-but-its-only-subtitle-scene-remake-748326.png (90x64 → 64x64)
# ✓ Processed: red-moon-336966.png (64x88 → 64x64)
# ✓ Processed: textmode-sawdusteater-v1-413433.png (64x64 → 64x64)
# ⊗ Skipped: bloody-brief-of-a-beckoning-bulletin-235769.png (540x540 - exceeds 512x512 limit)
# ✓ Processed: first-incantation-214736.gif (64x64 → 64x64)
# ✓ Processed: hylian-shield-094236.png (32x32 → 64x64)
# ✓ Processed: vandalism-news-75-title-picture-523509.png (90x64 → 64x64)
# ✓ Processed: juiceee-479881.png (64x64 → 64x64)
# ✓ Processed: daily-fall-368915.png (16x16 → 64x64)
# ✓ Processed: chainsaw-man-denji-pixel-art-775246.png (73x64 → 64x64)
# ✓ Processed: plicate-151541.png (64x64 → 64x64)
# ✓ Processed: vistas-de-verano-nov-471150.png (74x64 → 64x64)
# ✓ Processed: pokemon-player-search-system-105261.png (64x106 → 64x64)
# ✓ Processed: pink-winter-535264.png (64x89 → 64x64)
# ✓ Processed: celestial-tension-019612.png (64x64 → 64x64)
# ✓ Processed: rumia-595986.png (64x64 → 64x64)
# ✓ Processed: queen-of-shadows-324714.png (64x64 → 64x64)
# ✓ Processed: 3d-apple-pico-cad-650270.gif (64x64 → 64x64)
# ✓ Processed: arm-lex-083454.png (64x64 → 64x64)
# ✓ Processed: light-in-the-dark-014055.png (64x64 → 64x64)
# ✓ Processed: cd-spinning-490614.gif (64x64 → 64x64)
# ✓ Processed: first-pixel-art-634872.png (64x64 → 64x64)
# ✓ Processed: eternal-bliss-467664.png (66x64 → 64x64)
# ✓ Processed: mushrooms-437266.png (79x64 → 64x64)
# ✓ Processed: bubblegum-rock-learn-music-player-karaoke-prototype-892231.png (54x47 → 64x64)
# ⊗ Skipped: direct-794682.png (128x256, ratio: 0.50 - too tall)
# ✓ Processed: mays-offer-414600.png (64x64 → 64x64)
# ✓ Processed: love-grapes-795326.png (48x56 → 64x64)
# ✓ Processed: gold-dragon-755738.png (85x64 → 64x64)
# ✓ Processed: dragon-778813.png (64x64 → 64x64)
# ✓ Processed: fish-560451.png (64x113 → 64x64)
# ✓ Processed: which-is-are-you-558923.png (64x64 → 64x64)
# ✓ Processed: mobius-655295.png (64x93 → 64x64)
# ✓ Processed: mobile-legends-sprite-046-odette-741849.png (64x64 → 64x64)
# ✓ Processed: drink-on-a-beach-348299.png (64x64 → 64x64)
# ✓ Processed: the-god-created-by-monsters-and-was-condemned-to-live-347469.png (89x64 → 64x64)
# ✓ Processed: a-girl-035918.png (96x64 → 64x64)
# ✓ Processed: winter-grass-328815.png (32x32 → 64x64)
# ✓ Processed: camilly-village-plot-158161.gif (64x64 → 64x64)
# ⊗ Skipped: empowered-mortal-draw-605416.gif (864x576 - exceeds 512x512 limit)
# ✓ Processed: crabby-984585.png (50x50 → 64x64)
# ✓ Processed: lion-warrior-leona-rail-mockup-928599.png (71x64 → 64x64)
# ✓ Processed: oopsi-515933.png (64x68 → 64x64)
# ✓ Processed: triforce-loop-456926.gif (64x64 → 64x64)
# ⊗ Skipped: shiori-989382.gif (224x112, ratio: 2.00 - too wide)
# ✓ Processed: isometric-cube-mermaid-516023.gif (64x64 → 64x64)
# ✓ Processed: flower-679060.png (32x32 → 64x64)
# ✓ Processed: magic-477780.png (73x64 → 64x64)
# ✓ Processed: back-from-break-of-stuffs-477026.png (102x64 → 64x64)
# ⊗ Skipped: the-ultimate-nobody-797801.png (992x992 - exceeds 512x512 limit)
# ✓ Processed: sunlit-solitude-154280.png (64x85 → 64x64)
# ✓ Processed: tye-mossfoot-and-bethany-261298.png (64x64 → 64x64)
# ✓ Processed: poke-rasengan-358278.png (64x81 → 64x64)
# ✓ Processed: reminding-u-poster-1-321927.png (85x64 → 64x64)
# ⊗ Skipped: wolfenstein-3d-soldier-203710.png (22x48, ratio: 0.46 - too tall)
# ✓ Processed: lil-guy-291937.png (64x64 → 64x64)
# ⊗ Skipped: pallete-example-reupload-due-to-pallete-mistake-464888.png (37x104, ratio: 0.36 - too tall)
# ✓ Processed: three-one-bit-mountains-274745.gif (64x82 → 64x64)
# ✓ Processed: holla-holla-get-gold-coin-843163.png (16x16 → 64x64)
# ✓ Processed: feudal-industry-078127.png (113x64 → 64x64)
# ✓ Processed: resident-evil-536839.png (64x64 → 64x64)
# ✓ Processed: shine-036196.png (64x64 → 64x64)
# ✓ Processed: ice-age-of-the-dead-pixelween-2024-week-2-submission-143785.png (64x91 → 64x64)
# ✓ Processed: pirate-woman-710594.png (48x48 → 64x64)
# ✓ Processed: plantilla-de-personaje-animacion-de-caminar-940309.gif (64x64 → 64x64)
# ✓ Processed: troupe-master-grimm-418465.png (64x64 → 64x64)
# ✓ Processed: cascading-sanity-is-only-a-topple-away-816019.gif (64x80 → 64x64)
# ✓ Processed: fish-cloud-watching-885741.png (48x48 → 64x64)
# ✓ Processed: mana-570088.png (64x64 → 64x64)
# ✓ Processed: ominous-eye-290584.png (98x64 → 64x64)
# ✓ Processed: thermonuclear-sword-573007.png (64x64 → 64x64)
# ✓ Processed: lost-in-transmission-687012.png (64x81 → 64x64)
# ✓ Processed: belial-running-512296.gif (64x64 → 64x64)
# ✓ Processed: alien-rocks-013151.png (98x64 → 64x64)
# ⊗ Skipped: moonlit-fields-199200.png (64x32, ratio: 2.00 - too wide)
# ✓ Processed: low-poly-ducky-086436.gif (64x64 → 64x64)
# ✓ Processed: teto-my-beloved-311631.png (64x64 → 64x64)
# ✓ Processed: kirby-soda-108119.png (80x64 → 64x64)
# ⊗ Skipped: oot-animation-633978.gif (1024x1024 - exceeds 512x512 limit)
# ⊗ Skipped: iara-repeated-tree-pruned-tree-882979.png (640x640 - exceeds 512x512 limit)
# ✓ Processed: only-for-good-never-for-evil-504359.png (64x86 → 64x64)
# ✓ Processed: a-mug-of-beer-660305.png (64x64 → 64x64)
# ✓ Processed: waves-688386.png (88x64 → 64x64)
# ✓ Processed: oyasi-602054.png (69x64 → 64x64)
# ✓ Processed: iconic-764118.png (80x64 → 64x64)
# ✓ Processed: pohpoh-214611.png (64x64 → 64x64)
# ✓ Processed: celestia-208786.png (64x64 → 64x64)
# ✓ Processed: a-poro-in-freljord-262632.gif (64x64 → 64x64)
# ✓ Processed: rpg-maker-mv-mz-layout-icon-142765.png (64x80 → 64x64)
# ✓ Processed: space-banana-043418.gif (71x64 → 64x64)
# ✓ Processed: apple-glicht-effect-279549.gif (32x32 → 64x64)
# ⊗ Skipped: faint-whispers-438122.png (120x50, ratio: 2.40 - too wide)
# ✓ Processed: nocturnal-raccoon-010278.png (32x32 → 64x64)
# ✓ Processed: maneki-neko-965490.png (41x41 → 64x64)
# ✓ Processed: blackmask-cutscene-layout-305585.png (113x64 → 64x64)
# ⊗ Skipped: cloud-castle-957558.png (256x128, ratio: 2.00 - too wide)
# ✓ Processed: gg-fanart-106204.png (64x80 → 64x64)
# ⊗ Skipped: lost-found-701782.png (244x116, ratio: 2.10 - too wide)
# ✓ Processed: reimu-256720.png (64x64 → 64x64)
# ✓ Processed: under-the-fig-tree-863843.png (64x64 → 64x64)
# ✓ Processed: effusion-458008.png (64x64 → 64x64)
# ✓ Processed: skeleton-candle-tarot-225230.png (64x64 → 64x64)
# ✓ Processed: toilet-793217.png (16x16 → 64x64)
# ✓ Processed: dragons-castle-414981.png (113x64 → 64x64)
# ✓ Processed: shoto-todoroki-394867.png (64x96 → 64x64)
# ✓ Processed: cactus-brasilis-191663.gif (32x32 → 64x64)
# ✓ Processed: teddy-bear-896968.png (64x64 → 64x64)
# ✓ Processed: fetter-410080.png (64x64 → 64x64)
# ✓ Processed: shinomiya-kaguya-559295.png (64x64 → 64x64)
# ✓ Processed: retreat-993813.png (64x64 → 64x64)
# ✓ Processed: one-apple-a-day-319893.png (32x32 → 64x64)
# ✓ Processed: plants-vs-zombies-888414.png (71x64 → 64x64)
# ✓ Processed: pastel-moon-420597.png (64x86 → 64x64)
# ✓ Processed: symbiosis-617504.png (64x64 → 64x64)
# ✓ Processed: godspeed-011159.png (79x64 → 64x64)
# ✓ Processed: super-smash-bros-170353.png (71x64 → 64x64)
# ⊗ Skipped: idle-animation-for-game-im-making-802269.gif (1152x1152 - exceeds 512x512 limit)
# ✓ Processed: doctors-hat-170615.png (32x32 → 64x64)
# ✓ Processed: optimus-prime-399355.png (64x101 → 64x64)
# ✓ Processed: the-pale-depths-946085.png (88x64 → 64x64)
# ⊗ Skipped: stegosaurus-475705.png (124x64, ratio: 1.94 - too wide)
# ✓ Processed: spring-521665.png (64x64 → 64x64)
# ⊗ Skipped: a-heavy-temporal-storm-458069.png (128x64, ratio: 2.00 - too wide)
# ✓ Processed: wlvrn-784155.png (64x64 → 64x64)
# ✓ Processed: new-ray-and-his-true-form-raien-020261.png (64x64 → 64x64)
# ✓ Processed: norwegian-defense-184415.png (64x64 → 64x64)
# ✓ Processed: hornet-328031.png (64x64 → 64x64)
# ✓ Processed: gbstyle-minimal-view-part1-968991.png (64x64 → 64x64)
# ✓ Processed: gumskull-748718.png (64x64 → 64x64)
# ✓ Processed: cavern-town-023391.png (100x64 → 64x64)
# ✓ Processed: 8bit-big-nose-head-009792.png (32x32 → 64x64)
# ⊗ Skipped: bubblegum-play-learn-web-laptop-prototype-676408.png (640x896 - exceeds 512x512 limit)
# ✓ Processed: the-candle-of-destiny-759891.png (64x64 → 64x64)
# ✓ Processed: gone-fishin-957637.gif (28x28 → 64x64)
# ✓ Processed: witch-with-frog-776411.png (32x32 → 64x64)
# ✓ Processed: 52-nd-730785.png (64x64 → 64x64)
# ✓ Processed: hot-coco-625919.png (64x64 → 64x64)
# ✓ Processed: sam-xing-718014.png (58x58 → 64x64)
# ✓ Processed: froggyfall-57-forest-floor-leaves-625255.png (71x64 → 64x64)
# ✓ Processed: just-a-little-hallucination-837269.png (64x64 → 64x64)
# ✓ Processed: pixel-portrait-911672.png (64x107 → 64x64)
# ✓ Processed: the-grim-reaper-396755.png (64x91 → 64x64)
# ✓ Processed: time-to-whack-some-slimes-and-get-gp-825465.gif (106x64 → 64x64)
# ✓ Processed: angel-falls-988454.gif (64x64 → 64x64)
# ✓ Processed: a-view-467356.png (64x64 → 64x64)
# ⊗ Skipped: tree-redraw-046142.png (128x64, ratio: 2.00 - too wide)
# ✓ Processed: hatsune-miku-055245.png (64x64 → 64x64)
# ✓ Processed: when-their-hands-touched-a-warmth-spread-534852.png (64x64 → 64x64)
# ✓ Processed: reds-charmander-493219.png (64x64 → 64x64)
# ✓ Processed: i-want-what-i-deserve-the-world-chico-and-whats-in-it-364404.png (64x87 → 64x64)
# ✓ Processed: nene-picos-school-funny-355147.png (50x57 → 64x64)
# ✓ Processed: a-bun-bun-463750.png (32x32 → 64x64)
# ✓ Processed: my-dancing-avatar-876996.gif (64x64 → 64x64)
# ✓ Processed: meremayde-animation-beta-243177.gif (64x64 → 64x64)
# ✓ Processed: world-machine-custom-design-228351.gif (64x64 → 64x64)
# ✓ Processed: signs-of-life-760703.png (64x85 → 64x64)
# ✓ Processed: mizuki-719661.png (64x88 → 64x64)
# ✓ Processed: japanese-maple-072625.gif (64x64 → 64x64)
# ✓ Processed: mobile-legends-sprite-055-angela-836165.png (64x64 → 64x64)
# ✓ Processed: the-lords-bauhome-201371.png (64x96 → 64x64)
# ✓ Processed: bourgeon-718100.png (64x64 → 64x64)
# ✓ Processed: mtg-basic-land-set-swamp-390391.png (64x97 → 64x64)
# ✓ Processed: inktober-day-1-backpack-582671.png (64x64 → 64x64)
# ✓ Processed: bird-8-901629.png (64x64 → 64x64)
# ✓ Processed: some-sword-496994.png (64x64 → 64x64)
# ✓ Processed: sleepy-40-847052.png (64x64 → 64x64)
# ✓ Processed: sad-little-man-830376.png (64x64 → 64x64)
# ✓ Processed: bocchi-za-rock-lospec-daily-sept-22nd-2024-939134.png (64x64 → 64x64)
# ⊗ Skipped: spooky-vibes-445064.png (1280x1280 - exceeds 512x512 limit)
# ✓ Processed: alternative-pixels-301040.png (48x39 → 64x64)
# ✓ Processed: duck-511593.gif (64x64 → 64x64)
# ✓ Processed: invincible-292375.png (64x64 → 64x64)
# ✓ Processed: kick-bill-volume-2-lemon-meringue-763933.png (75x64 → 64x64)
# ✓ Processed: somewhere-out-there-088062.png (113x64 → 64x64)
# ✓ Processed: claire-fullbody-667551.png (64x64 → 64x64)
# ✓ Processed: ghoul-mask-ghost-bc-136660.png (64x96 → 64x64)
# ✓ Processed: ball-lightning-830871.png (64x64 → 64x64)
# ✓ Processed: bellosom-lospec-daily-grass-november-1st-2024-962832.png (64x64 → 64x64)
# ✓ Processed: medieval-man-492945.png (64x64 → 64x64)
# ✓ Processed: daily-challenge-tundra-153490.png (96x64 → 64x64)
# ✓ Processed: two-face-poster-369777.png (64x64 → 64x64)
# ✓ Processed: a-calm-night-265113.png (64x64 → 64x64)
# ✓ Processed: sweet-byte-cherries-722087.gif (32x32 → 64x64)
# ✓ Processed: sleeping-cat-512452.png (64x64 → 64x64)
# ✓ Processed: half-switch-499510.png (16x16 → 64x64)
# ✓ Processed: hornet-32x32-754361.png (32x32 → 64x64)
# ✓ Processed: cursed-lava-golem-knight-pixel-art-animation-637524.gif (114x64 → 64x64)
# ✓ Processed: ace-of-arrows-433014.png (64x89 → 64x64)
# ✓ Processed: shiny-rowlet-455480.png (64x64 → 64x64)
# ✓ Processed: got-to-start-somewhere-825661.png (16x16 → 64x64)
# ✓ Processed: resting-man-animation-624940.gif (32x32 → 64x64)
# ✓ Processed: new-design-komet-komodo-744148.gif (64x64 → 64x64)
# ✓ Processed: leonardpng-030665.png (64x64 → 64x64)
# ✓ Processed: tourist-trap-tribute-210074.gif (64x76 → 64x64)
# ✓ Processed: city-142589.png (102x64 → 64x64)
# ✓ Processed: old-car-193820.png (64x64 → 64x64)
# ✓ Processed: examination-763973.png (64x64 → 64x64)
# ✓ Processed: mordin-solus-mass-effect-612856.png (64x64 → 64x64)
# ✓ Processed: pixel-daily-celebration-211381.png (85x64 → 64x64)
# ✓ Processed: meg-263196.png (64x64 → 64x64)
# ✓ Processed: charizard-589225.png (64x64 → 64x64)
# ⊗ Skipped: nearing-event-horizon-708375.png (384x128, ratio: 3.00 - too wide)
# ✓ Processed: hammer-561621.png (32x32 → 64x64)
# ✓ Processed: 2099-979034.png (64x72 → 64x64)
# ✓ Processed: the-legends-of-zelda-majoras-mask-787945.png (64x64 → 64x64)
# ✓ Processed: the-pixel-express-848414.png (108x64 → 64x64)
# ✓ Processed: datathingy-030725.png (96x64 → 64x64)
# ✓ Processed: winged-602864.png (64x64 → 64x64)
# ✓ Processed: forest-148642.png (64x96 → 64x64)
# ✓ Processed: little-orange-2-480497.png (117x64 → 64x64)
# ✓ Processed: eggwhat-could-it-beeaster-542114.png (16x16 → 64x64)
# ✓ Processed: daily-house-bahay-kubo-095413.png (18x18 → 64x64)
# ✓ Processed: slime-wearing-a-scarf-835201.png (64x64 → 64x64)
# ✓ Processed: something-sword-like-870943.png (39x45 → 64x64)
# ✓ Processed: omg-secret-game-of-bugs-life-2-0o-complete-fake-111186.png (71x64 → 64x64)
# ✓ Processed: the-beauty-of-annihilation-108660.png (64x81 → 64x64)
# ✓ Processed: inequality-291779.png (64x64 → 64x64)
# ✓ Processed: scarlett-rage-140366.gif (64x64 → 64x64)
# ✓ Processed: rex-077327.png (64x66 → 64x64)
# ✓ Processed: pixelween-2022-horror-game-mock-ups-210191.png (64x72 → 64x64)
# ✓ Processed: password-401741.gif (108x64 → 64x64)
# ✓ Processed: house-in-the-trees-daily-pixels-8-466971.png (71x64 → 64x64)
# ✓ Processed: jumping-slime-809470.gif (32x32 → 64x64)
# ✓ Processed: uno-reverse-card-694877.png (64x64 → 64x64)
# ✓ Processed: cameron-504188.png (64x64 → 64x64)
# ✓ Processed: 003-ticket-booth-954086.png (16x16 → 64x64)
# ✓ Processed: alce-907788.png (64x69 → 64x64)
# ⊗ Skipped: gera-pixeled-764872.png (877x791 - exceeds 512x512 limit)
# ⊗ Skipped: pixel-art-calico-492957.png (790x830 - exceeds 512x512 limit)
# ✓ Processed: snowed-in-009937.png (64x89 → 64x64)
# ✓ Processed: permanent-night-071250.png (64x64 → 64x64)
# ✓ Processed: windows-95-279402.png (80x64 → 64x64)
# ⊗ Skipped: dino-animation-358351.gif (1493x790 - exceeds 512x512 limit)
# ✓ Processed: apell-220066.png (48x48 → 64x64)
# ✓ Processed: alien-player-select-392900.png (64x64 → 64x64)
# ✓ Processed: yharim-god-killer-426447.png (48x48 → 64x64)
# ✓ Processed: poseidon-399811.png (103x64 → 64x64)
# ✓ Processed: bubblegum-play-learn-my-zone-smart-televison-prototype-122602.png (28x51 → 64x64)
# ✓ Processed: putricia-the-corpse-flower-748979.gif (64x64 → 64x64)
# ✓ Processed: get-out-of-this-nightmare-244368.png (96x64 → 64x64)
# ✓ Processed: espial-338606.png (64x64 → 64x64)
# ⊗ Skipped: demon-blood-sword-839357.png (80x151, ratio: 0.53 - too tall)
# ✓ Processed: his-name-is-ben-he-dont-like-to-take-picture-im-sorry-507574.png (64x64 → 64x64)
# ✓ Processed: game-level-604774.png (64x64 → 64x64)
# ✓ Processed: first-asrt-712777.png (64x64 → 64x64)
# ✓ Processed: ace-of-cups-044509.png (64x89 → 64x64)
# ✓ Processed: warm-milk-813165.png (16x16 → 64x64)
# ✓ Processed: false-reprieve-005298.png (64x64 → 64x64)
# ✓ Processed: half-852773.png (16x16 → 64x64)
# ⊗ Skipped: crossfoods-all-189801.gif (768x768 - exceeds 512x512 limit)
# ✓ Processed: deadpoolwolverine-969445.png (64x106 → 64x64)
# ✓ Processed: waylon-novakid-803691.png (64x64 → 64x64)
# ⊗ Skipped: pixelween-week-1-victorian-apocalypse-983328.png (424x200, ratio: 2.12 - too wide)
# ✓ Processed: sage-mode-691433.png (64x118 → 64x64)
# ✓ Processed: weird-dog-271156.png (64x64 → 64x64)
# ✓ Processed: detachment-219539.png (64x64 → 64x64)
# ✓ Processed: redio-head-044227.png (64x64 → 64x64)
# ✓ Processed: ap-coin-icon-653917.gif (28x28 → 64x64)
# ✓ Processed: cuckoo-wasp-gif-193991.gif (64x64 → 64x64)
# ✓ Processed: shadowblade-157744.png (64x64 → 64x64)
# ✓ Processed: windows-3000-in-color-455449.png (108x64 → 64x64)
# ✓ Processed: steve-clark-the-traffic-warlock-744881.png (64x64 → 64x64)
# ✓ Processed: did-you-eat-today-464193.png (64x64 → 64x64)
# ✓ Processed: horse-walk-330105.gif (32x32 → 64x64)
# ✓ Processed: hot-food-watch-out-910166.png (64x64 → 64x64)
# ✓ Processed: horizon-beyond-359927.png (64x64 → 64x64)
# ✓ Processed: metro-634447.png (64x64 → 64x64)
# ✓ Processed: lea-quizzical-609739.png (64x70 → 64x64)
# ✓ Processed: poise-933102.png (64x64 → 64x64)
# ✓ Processed: pancakes-at-breakfast-745478.png (64x100 → 64x64)
# ✓ Processed: mysterious-potion-644600.png (46x46 → 64x64)
# ✓ Processed: cafe-698426.gif (64x64 → 64x64)
# ✓ Processed: sprirted-away-886049.png (67x64 → 64x64)
# ✓ Processed: team-fortress-2-shotgun-035765.gif (64x64 → 64x64)
# ⊗ Skipped: 15-dias-de-pixel-art-ronda1-452521.png (522x306 - exceeds 512x512 limit)
# ⊗ Skipped: crops-793904.png (128x64, ratio: 2.00 - too wide)
# ⊗ Skipped: finally-free-191847.png (464x120, ratio: 3.87 - too wide)
# ✓ Processed: quill-the-bee-gift-art-968884.gif (64x80 → 64x64)
# ✓ Processed: rainbow-rebellion-134218.png (64x64 → 64x64)
# ✓ Processed: jaws-16bit-game-mock-up-out-swim-the-shark-stage-320240-329981.gif (85x64 → 64x64)
# ✓ Processed: easy-563765.png (64x81 → 64x64)
# ✓ Processed: mushroom-901873.png (32x32 → 64x64)
# ⊗ Skipped: logo-others-991770.gif (300x100, ratio: 3.00 - too wide)
# ⊗ Skipped: wario-and-waluigi-583216.png (400x200, ratio: 2.00 - too wide)
# ✓ Processed: pixelday-2021-660591.png (64x64 → 64x64)
# ✓ Processed: suspicious-puddle-164304.gif (64x64 → 64x64)
# ✓ Processed: four-color-fungi-108234.gif (64x64 → 64x64)
# ✓ Processed: rock-tub-746046.png (112x64 → 64x64)
# ⊗ Skipped: 006xb-770608.png (640x880 - exceeds 512x512 limit)
# ✓ Processed: tropical-for-lospec-dailies-4-may-25-560924.png (96x64 → 64x64)
# ✓ Processed: elara-druid-of-noble-birth-205064.png (64x64 → 64x64)
# ✓ Processed: shes-just-hungry-dont-worry-354392.png (64x64 → 64x64)
# ✓ Processed: guess-we-makin-1bit-art-now-298866.png (113x64 → 64x64)
# ✓ Processed: shroom-house-264385.png (64x64 → 64x64)
# ✓ Processed: the-maiden-with-the-crystal-wings-639703.png (64x96 → 64x64)
# ✓ Processed: grapeboy-palette-bulbasuar-013057.png (64x64 → 64x64)
# ⊗ Skipped: cozy-043159.png (640x640 - exceeds 512x512 limit)
# ✓ Processed: rabbit-portrait-626005.gif (64x64 → 64x64)
# ✓ Processed: palhaco-409723.png (64x64 → 64x64)
# ⊗ Skipped: cold-boot-attack-173044.png (2048x1287 - exceeds 512x512 limit)
# ✓ Processed: 100-face-challange-1-9-733627.png (64x64 → 64x64)
# ✓ Processed: biggest-of-irons-981191.png (64x64 → 64x64)
# ✓ Processed: nothing-to-fear-491791.png (73x64 → 64x64)
# ✓ Processed: bubblegum-my-first-tap-learn-pad-prototype-249258.png (52x58 → 64x64)
# ✓ Processed: green-drink-515962.png (64x64 → 64x64)
# ⊗ Skipped: midna-374539.png (48x95, ratio: 0.51 - too tall)
# ✓ Processed: a-lents-guy-nes-new-version-462191.png (68x64 → 64x64)
# ✓ Processed: smoked-cubone-rump-cap-300594.gif (70x64 → 64x64)
# ✓ Processed: old-lighthouse-in-swamp-397323.png (80x64 → 64x64)
# ✓ Processed: my-name-is-megumin-697170.png (64x64 → 64x64)
# ✓ Processed: wood-490032.png (32x32 → 64x64)
# ✓ Processed: far-072946.png (64x64 → 64x64)
# ✓ Processed: self-portrait-124163.png (24x24 → 64x64)
# ✓ Processed: shadow-sprite-for-nes-761865.gif (32x32 → 64x64)
# ✓ Processed: super-amaro-bros-988732.png (64x64 → 64x64)
# ⊗ Skipped: a-flan-and-a-moon-327995.png (640x784 - exceeds 512x512 limit)
# ✓ Processed: fish-monster-440290.png (64x64 → 64x64)
# ⊗ Skipped: sunny-night-while-hiking-822144.png (640x360 - exceeds 512x512 limit)
# ✓ Processed: spitfire-246018.png (64x64 → 64x64)
# ✓ Processed: pretty-fly-for-a-grey-guy-323096.png (99x64 → 64x64)
# ✓ Processed: asta-992395.png (96x64 → 64x64)
# ✓ Processed: sprite-499470.png (32x32 → 64x64)
# ✓ Processed: gargantua-015862.png (113x64 → 64x64)
# ✓ Processed: star-529484.gif (16x16 → 64x64)
# ✓ Processed: blue-smoke-sesh-379267.png (96x64 → 64x64)
# ✓ Processed: carga-pesada-111302.gif (64x106 → 64x64)
# ✓ Processed: alchemy-555392.png (64x64 → 64x64)
# ⊗ Skipped: tranquil-afternoon-276397.png (250x125, ratio: 2.00 - too wide)
# ✓ Processed: spike-spiegel-097124.png (55x50 → 64x64)
# ✓ Processed: its-wooper-563520.png (71x64 → 64x64)
# ✓ Processed: somewhere-deep-in-time-and-space-816569.png (96x64 → 64x64)
# ✓ Processed: rhodo-nebula-778631.png (64x64 → 64x64)
# ✓ Processed: the-last-stamp-of-the-dodo-933114.png (64x68 → 64x64)
# ⊗ Skipped: slay-rock-224417.png (826x827 - exceeds 512x512 limit)
# ✓ Processed: battle-jester-356127.png (64x64 → 64x64)
# ✓ Processed: hornet-the-weaver-002349.png (64x91 → 64x64)
# ✓ Processed: paperboy-mad-557720.png (64x64 → 64x64)
# ✓ Processed: ring-of-enchantment-462994.png (54x54 → 64x64)
# ✓ Processed: minnion-gags-935548.png (64x101 → 64x64)
# ✓ Processed: miku-me-to-the-moon-592824.gif (64x64 → 64x64)
# ✓ Processed: north-751397.png (64x64 → 64x64)
# ✓ Processed: magical-platinum-lospec-daily-nov-15-2024-magical-634803.png (64x80 → 64x64)
# ✓ Processed: excalibur-emblem-773208.png (64x64 → 64x64)
# ✓ Processed: wildfire-198412.gif (113x64 → 64x64)
# ✓ Processed: the-globe-199439.png (71x64 → 64x64)
# ✓ Processed: luna-994742.png (64x64 → 64x64)
# ⊗ Skipped: grass-block-536969.png (400x173, ratio: 2.31 - too wide)
# ✓ Processed: just-a-little-guy-271464.png (64x64 → 64x64)
# ✓ Processed: sunset-141017.png (96x64 → 64x64)
# ✓ Processed: cyberpunk-sasha-gb-pixel-jam-submission-2024-530155.png (71x64 → 64x64)
# ✓ Processed: demiurge-635823.png (64x64 → 64x64)
# ✓ Processed: pixel-girl-character-design-027285.png (64x64 → 64x64)
# ✓ Processed: mystic-16-kitchen-854402.png (64x65 → 64x64)
# ✓ Processed: titan-warp-810658.png (113x64 → 64x64)
# ✓ Processed: sunset-in-country-474653.png (64x64 → 64x64)
# ✓ Processed: mimic-high-priestess-827659.gif (64x64 → 64x64)
# ✓ Processed: torchic-946389.png (32x32 → 64x64)
# ✓ Processed: caitly-153998.gif (64x110 → 64x64)
# ✓ Processed: knight-935968.png (64x64 → 64x64)
# ✓ Processed: pcg-tileset1-bold-123335.png (117x64 → 64x64)
# ⊗ Skipped: pixless-camera-test-804040.png (256x128, ratio: 2.00 - too wide)
# ✓ Processed: shield-786501.png (16x16 → 64x64)
# ✓ Processed: bartender-984317.png (64x64 → 64x64)
# ⊗ Skipped: old-pc-505361.png (1989x1238 - exceeds 512x512 limit)
# ✓ Processed: support-unit-class-q-765281.png (64x67 → 64x64)
# ✓ Processed: hypnomachy-369559.gif (64x78 → 64x64)
# ⊗ Skipped: purgatory-room-viii-257657.gif (1200x840 - exceeds 512x512 limit)
# ✓ Processed: letter-170500.png (16x16 → 64x64)
# ⊗ Skipped: edit-the-sad-parts-178087.png (1920x1080 - exceeds 512x512 limit)
# ✓ Processed: csgo-chicken-practice-animation-638197.gif (16x16 → 64x64)
# ⊗ Skipped: first-pixel-sprite-912512.gif (32x64, ratio: 0.50 - too tall)
# ⊗ Skipped: determination-906003.png (100x200, ratio: 0.50 - too tall)
# ✓ Processed: horeg-indonesia-vehicle-series-054174.png (64x64 → 64x64)
# ✓ Processed: planet-ninja-396354.png (54x46 → 64x64)
# ✓ Processed: pixel-anniversary-2025-250171.png (64x77 → 64x64)
# ⊗ Skipped: plink-logo-507421.png (735x549 - exceeds 512x512 limit)
# ✓ Processed: rock-with-holder-701490.png (48x48 → 64x64)
# ✓ Processed: carol-beep-boop-289620.png (64x76 → 64x64)
# ✓ Processed: maniac-miner-nes-style-sprites-mario-variant-incluided-591413.gif (85x64 → 64x64)
# ⊗ Skipped: sea-buddies-502089.png (1783x1079 - exceeds 512x512 limit)
# ✓ Processed: discharge-530510.png (64x65 → 64x64)
# ⊗ Skipped: blackveil-586470.gif (768x768 - exceeds 512x512 limit)
# ✓ Processed: ork-kor-229190.png (112x64 → 64x64)
# ✓ Processed: pssssst-come-here-kitty-kitty-pssssst-725569.png (64x64 → 64x64)
# ✓ Processed: petscii-birds-c64-demake-806300.png (90x64 → 64x64)
# ✓ Processed: deep-energy-703386.png (85x64 → 64x64)
# ✓ Processed: blast-043679.png (64x64 → 64x64)
# ✓ Processed: specter-693736.png (64x64 → 64x64)
# ⊗ Skipped: sala-antiga-brasileira-893085.png (1920x1080 - exceeds 512x512 limit)
# ✓ Processed: marry-xmas-413041.png (66x64 → 64x64)
# ✓ Processed: mobile-coffee-519473.png (64x64 → 64x64)
# ✓ Processed: tether-974057.png (64x80 → 64x64)
# ✓ Processed: character-study-873858.png (64x64 → 64x64)
# ✓ Processed: strawberry-potion-892961.png (32x32 → 64x64)
# ⊗ Skipped: anniversary-928336.png (480x94, ratio: 5.11 - too wide)
# ✓ Processed: ramen-747514.png (64x64 → 64x64)
# ✓ Processed: sir-shitbyrd-072929.png (64x64 → 64x64)
# ✓ Processed: a-nights-rest-472314.gif (113x64 → 64x64)
# ✓ Processed: portree-676031.png (85x64 → 64x64)
# ✓ Processed: eye-of-astarion-from-baldurs-gate-3-756926.png (64x70 → 64x64)
# ✓ Processed: helios-lighter-920340.gif (64x64 → 64x64)
# ⊗ Skipped: crystals-that-point-the-way-138548.png (256x128, ratio: 2.00 - too wide)
# ✓ Processed: egress-782220.png (64x64 → 64x64)
# ✓ Processed: the-flash-nes-game-mockup-096195.png (68x64 → 64x64)
# ✓ Processed: alien-abduction-848184.gif (102x64 → 64x64)
# ✓ Processed: skill-tree-concept-639190.png (64x82 → 64x64)
# ✓ Processed: another-planty-151802.png (64x64 → 64x64)
# ✓ Processed: cool-routine-077718.png (64x64 → 64x64)
# ✓ Processed: a-planet-164184.png (64x64 → 64x64)
# ✓ Processed: frieren-and-the-moon-092929.png (64x64 → 64x64)
# ✓ Processed: red-android-485443.png (93x64 → 64x64)
# ...
# ✓ Processed: mysterious-orb-in-the-cavern-784104.png (99x64 → 64x64)
# ✓ Processed: frogy-174528.png (32x32 → 64x64)
# ✓ Processed: gwen-tennyson-059686.png (64x76 → 64x64)
# ✓ Processed: frog-overseer-792798.png (64x64 → 64x64)
# ✓ Processed: madotsuki-244571.png (64x64 → 64x64)
# ⊗ Skipped: stamp-act-repeal-apush-apush-apush-504532.png (960x540 - exceeds 512x512 limit)
# ✓ Processed: mobile-legends-sprite-013-clint-553239.png (64x64 → 64x64)
# ✓ Processed: sir-this-is-a-disc-golf-area-754990.png (64x94 → 64x64)
# ✓ Processed: atmosphere-920280.png (64x64 → 64x64)
# ✓ Processed: wasteland-562483.png (104x64 → 64x64)
# ✓ Processed: ainz-ooal-gown-007201.png (64x68 → 64x64)
# ✓ Processed: pale-blue-138454.png (64x64 → 64x64)
# ✓ Processed: the-forgotten-entry-791678.png (64x64 → 64x64)
# ✓ Processed: halloween-047470.png (64x64 → 64x64)
# ✓ Processed: vermin-221516.gif (64x64 → 64x64)
# ✓ Processed: big-chiller-783047.gif (16x16 → 64x64)
# ⊗ Skipped: claw-monster-217617.png (640x640 - exceeds 512x512 limit)
# ✓ Processed: pokebola-078966.png (64x64 → 64x64)
# ✓ Processed: twin-cultists-463574.png (64x111 → 64x64)
# ✓ Processed: end-739705.png (64x64 → 64x64)
# ⊗ Skipped: saint-gamer-514395.gif (390x620 - exceeds 512x512 limit)
# ✓ Processed: old-cowboy-002203.png (64x64 → 64x64)
# ✓ Processed: set-of-characters-in-megaman-style-088703.png (73x64 → 64x64)
# ✓ Processed: speedrunner-herobrin-418052.png (64x111 → 64x64)
# ✓ Processed: office-wall-905889.png (64x64 → 64x64)
# ✓ Processed: face-in-the-dark-for-the-daily-842843.png (64x64 → 64x64)
# ⊗ Skipped: micronational-uniforms-republic-of-peachtree-500578.png (400x200, ratio: 2.00 - too wide)
# ✓ Processed: bonfire-402408.png (64x108 → 64x64)
# ✓ Processed: just-a-cactus-and-nothing-more-625913.png (64x64 → 64x64)
# ✓ Processed: the-lancer-fun-squad-935503.png (64x64 → 64x64)
# ✓ Processed: pudim-014599.png (76x64 → 64x64)
# ✓ Processed: theres-something-wrong-with-the-world-527562.png (64x89 → 64x64)
# ✓ Processed: pixel-484154.gif (85x64 → 64x64)
# ✓ Processed: oc-rhythm-493977.gif (64x81 → 64x64)
# ✓ Processed: native-pigface-159706.png (64x64 → 64x64)
# ✓ Processed: yevna-from-yog-sothoths-yard-2-815894.png (64x85 → 64x64)
# ✓ Processed: reforged-knight-147543.png (65x64 → 64x64)
# ✓ Processed: garfield-762735.png (64x64 → 64x64)
# ✓ Processed: my-pet-rock-is-named-jonathan-338819.png (32x32 → 64x64)
# ✓ Processed: corrupted-rogue-archer-854743.png (64x64 → 64x64)
# ✓ Processed: 50-power-attack-194329.png (64x64 → 64x64)
# ✓ Processed: mobile-legends-sprite-038-vexana-042540.png (64x64 → 64x64)
# ✓ Processed: thief-outpost-165125.png (113x64 → 64x64)
# ✓ Processed: propaganda-480981.png (64x99 → 64x64)
# ✓ Processed: shroomtoad-449172.png (64x64 → 64x64)
# ⊗ Skipped: toadleaf-artfight-attack-animation-976127.gif (906x828 - exceeds 512x512 limit)
# ✓ Processed: lost-416969.png (64x96 → 64x64)
# ✓ Processed: dragon-tiling-from-tile-set-662616.png (64x64 → 64x64)
# ✓ Processed: felicia-2025-130684.png (64x64 → 64x64)
# ⊗ Skipped: at-the-soda-shop-740091.png (64x128, ratio: 0.50 - too tall)
# ⊗ Skipped: noname-project-4-part2-707502.png (640x360 - exceeds 512x512 limit)
# ✓ Processed: inktober-day-3-boots-011698.png (64x64 → 64x64)
# ✓ Processed: the-facades-fade-557771.png (64x64 → 64x64)
# ✓ Processed: flesh-bulb-862804.gif (64x64 → 64x64)
# ✓ Processed: ran-090340.png (64x64 → 64x64)
# ⊗ Skipped: circles-924794.png (1920x1080 - exceeds 512x512 limit)
# ⊗ Skipped: gorgon-955831.png (128x256, ratio: 0.50 - too tall)
# ✓ Processed: y-sinx-376333.png (90x64 → 64x64)
# ✓ Processed: ezekiel-2517-727906.png (64x64 → 64x64)
# ✓ Processed: germinal-236493.png (64x64 → 64x64)
# ✓ Processed: rat-cheese-972478.gif (64x79 → 64x64)
# ✓ Processed: beyond-the-world-793875.png (76x64 → 64x64)
# ✓ Processed: isometric-garage-803973.gif (64x64 → 64x64)
# ✓ Processed: lacewing-angel-471417.png (64x100 → 64x64)
# ✓ Processed: sorceress-879780.png (72x64 → 64x64)
# ✓ Processed: unseen-monsters-663539.png (113x64 → 64x64)
# ⊗ Skipped: liquid-flow-342451.png (128x255, ratio: 0.50 - too tall)
# ✓ Processed: bowler-hat-lady-554000.png (64x64 → 64x64)
# ✓ Processed: bray-577218.png (48x48 → 64x64)
# ⊗ Skipped: a-tiny-animated-zeldalike-mockup-091910.gif (576x576 - exceeds 512x512 limit)
# ⊗ Skipped: river-farm-837540.png (640x320 - exceeds 512x512 limit)
# ✓ Processed: human-strength-479137.png (64x81 → 64x64)
# ✓ Processed: new-pfp-dunkleosteus-903260.png (64x64 → 64x64)
# ✓ Processed: animation-he-really-is-everywhere-255369.gif (64x64 → 64x64)
# ✓ Processed: poizma-788939.png (64x64 → 64x64)
# ✓ Processed: fall-grass-668391.png (32x32 → 64x64)
# ⊗ Skipped: space-travel-is-boring-279756.png (1920x1080 - exceeds 512x512 limit)
# ✓ Processed: pico-cad-pumpkin-basket-461399.gif (64x64 → 64x64)
# ✓ Processed: potions-264623.png (64x36 → 64x64)
# ✓ Processed: 08152024-daily-movie-986383.png (64x64 → 64x64)
# ⊗ Skipped: mario-resprites-739330.png (128x64, ratio: 2.00 - too wide)
# ✓ Processed: tars-iv-148010.png (102x64 → 64x64)
# ✓ Processed: big-hand-136297.png (96x64 → 64x64)
# ✓ Processed: holiday-tharja-616262.png (64x85 → 64x64)
# ✓ Processed: big-blue-517076.png (106x64 → 64x64)
# ✓ Processed: arcana-712157.png (64x64 → 64x64)
# ✓ Processed: pixel-daily-liquid-311813.png (85x64 → 64x64)
# ✓ Processed: forest-environment-197832.png (113x64 → 64x64)
# ✓ Processed: guts-from-berserk-213267.png (52x52 → 64x64)
# ✓ Processed: red-demon-712493.png (64x64 → 64x64)
# ⊗ Skipped: lady-998781.png (924x782 - exceeds 512x512 limit)
# ✓ Processed: cute-blue-duck-in-water-335025.png (64x64 → 64x64)
# ✓ Processed: afraid-be-not-785338.png (70x64 → 64x64)
# ⊗ Skipped: sandy-planet-266587.png (1500x500 - exceeds 512x512 limit)
# ✓ Processed: inverted-584230.png (15x28 → 64x64)
# ⊗ Skipped: pattern-recognition-602256.png (1920x1080 - exceeds 512x512 limit)
# ✓ Processed: mustacheslinger-339558.gif (64x64 → 64x64)
# ✓ Processed: red-planet-236128.png (64x64 → 64x64)
# ✓ Processed: 9-characters-portraits-313383.png (64x64 → 64x64)
# ✓ Processed: chito-alcohol-400620.png (71x64 → 64x64)
# ✓ Processed: braqito-sings-148059.png (64x78 → 64x64)
# ⊗ Skipped: scifi-ice-planet-542041.png (128x256, ratio: 0.50 - too tall)
# ⊗ Skipped: knight-animation-practice-16x16-basic-movement-391201.gif (590x295 - exceeds 512x512 limit)
# ✓ Processed: player-one-start-zx-spectrum-293326.png (85x64 → 64x64)
# ✓ Processed: dwight-with-the-pumpkin-stuck-kkk-773290.png (32x32 → 64x64)
# ⊗ Skipped: blk-nx64-banner-645954.png (463x125, ratio: 3.70 - too wide)
# ✓ Processed: embered-932374.png (64x82 → 64x64)
# ✓ Processed: daily-pixels-1-354232.png (71x64 → 64x64)
# ✓ Processed: day-1-tree-499352.png (64x64 → 64x64)
# ✓ Processed: a-new-dawn-903560.png (64x84 → 64x64)
# ✓ Processed: knight-762251.png (64x64 → 64x64)
# ⊗ Skipped: akira-drift-506975.png (640x640 - exceeds 512x512 limit)
# ⊗ Skipped: 15-dias-de-pixel-art-ronda-2-764216.png (646x471 - exceeds 512x512 limit)
# ✓ Processed: clover-dance-mini-version-915708.gif (64x70 → 64x64)
# ✓ Processed: two-group-espresso-machine-142308.png (86x64 → 64x64)
# ✓ Processed: fungi-026874.png (64x64 → 64x64)
# ✓ Processed: where-stars-actually-come-from-609366.png (64x64 → 64x64)
# ✓ Processed: argentinian-starfish-508106.png (64x64 → 64x64)
# ✓ Processed: robin-757055.png (64x64 → 64x64)
# ✓ Processed: forgotten-sword-584248.png (64x64 → 64x64)
# ✓ Processed: the-tree-on-a-hill-pm-249120.png (80x64 → 64x64)
# ✓ Processed: bench-in-the-rain-158048.png (64x64 → 64x64)
# ✓ Processed: fallout-team-377483.png (64x64 → 64x64)
# ✓ Processed: chryssalid-x-com-1994-251230.png (64x64 → 64x64)
# ⊗ Skipped: combine-group-051446.png (153x59, ratio: 2.59 - too wide)
# ✓ Processed: stare-766734.png (64x76 → 64x64)
# ⊗ Skipped: items-276120.png (329x124, ratio: 2.65 - too wide)
# ✓ Processed: tameless-827486.png (64x64 → 64x64)
# ⊗ Skipped: vaelrun2-152782.png (640x360 - exceeds 512x512 limit)
# ✓ Processed: the-witchs-lab-706375.png (81x64 → 64x64)
# ⊗ Skipped: cthulhu-824934.gif (1280x1280 - exceeds 512x512 limit)
# ✓ Processed: red-squid-551032.png (64x64 → 64x64)
# ✓ Processed: pagoda-328018.gif (64x64 → 64x64)
# ✓ Processed: belinda-242588.png (25x25 → 64x64)
# ✓ Processed: mystical-329932.png (64x64 → 64x64)
# ✓ Processed: autumn-solitude-303527.png (64x64 → 64x64)
# ✓ Processed: bunnyroom1-785538.png (64x64 → 64x64)
# ⊗ Skipped: void-breaker-694265.png (320x136, ratio: 2.35 - too wide)
# ✓ Processed: mar10-day-292649.png (68x64 → 64x64)
# ⊗ Skipped: purgatory-room-vii-329738.gif (1200x840 - exceeds 512x512 limit)
# ✓ Processed: idk-hungry-493209.png (64x64 → 64x64)
# ✓ Processed: 1-bit-ish-landscape-363347.png (71x64 → 64x64)
# ⊗ Skipped: castle-town-526656.png (432x712 - exceeds 512x512 limit)
# ✓ Processed: sunset-city-829051.png (102x64 → 64x64)
# ⊗ Skipped: all-goldies-power-cards-645703.png (197x40, ratio: 4.92 - too wide)
# ✓ Processed: daily-2-219362.png (64x64 → 64x64)
# ✓ Processed: gooball-smoking-a-cigarette-438816.png (64x64 → 64x64)
# ✓ Processed: its-me-again-865044.png (42x42 → 64x64)
# ⊗ Skipped: yellow-hoody-in-the-rain-200830.gif (480x560 - exceeds 512x512 limit)
# ✓ Processed: moonlit-pines-508561.png (64x64 → 64x64)
# ✓ Processed: 1bit-knight-895809.png (64x64 → 64x64)
# ⊗ Skipped: transformation-551248.png (116x30, ratio: 3.87 - too wide)
# ✓ Processed: windows-3000-011884.png (108x64 → 64x64)
# ✓ Processed: regina-pin-up-artwork-372523.png (64x64 → 64x64)
# ✓ Processed: dont-wander-off-684583.png (95x64 → 64x64)
# ✓ Processed: rusty-coast-845035.png (71x64 → 64x64)
# ✓ Processed: smb-world-1-1-for-apple-115902.png (112x64 → 64x64)
# ✓ Processed: dmfd-redraw-670887.png (96x64 → 64x64)
# ✓ Processed: mobile-legends-sprite-025-kagura-362324.png (64x64 → 64x64)
# ✓ Processed: zipperman-446986.png (64x85 → 64x64)
# ✓ Processed: burn-them-all-304597.png (64x69 → 64x64)
# ⊗ Skipped: same-as-cash-126774.png (120x260, ratio: 0.46 - too tall)
# ✓ Processed: bread-991059.png (64x64 → 64x64)
# ⊗ Skipped: terrys-cap-931379.gif (768x768 - exceeds 512x512 limit)
# ✓ Processed: hillside-007076.png (64x98 → 64x64)
# ✓ Processed: jaminho-simulator-148128.gif (64x64 → 64x64)
# ✓ Processed: bitwit-icon-576156.png (32x32 → 64x64)
# ✓ Processed: jin-roh-kerberos-panzer-corps-suit-394646.png (64x86 → 64x64)
# ✓ Processed: glory-to-arstotzka-084718.png (107x64 → 64x64)
# ✓ Processed: edify-602044.png (64x64 → 64x64)
# ⊗ Skipped: ictywsid-491382.png (900x900 - exceeds 512x512 limit)
# ✓ Processed: abstcharact1-548946.png (64x64 → 64x64)
# ✓ Processed: just-a-chill-guy-607813.png (64x64 → 64x64)
# ✓ Processed: lospec-daily-3-achievement-088306.png (64x78 → 64x64)
# ✓ Processed: my-splatoon-10th-anniversary-art-piece-870907.png (74x64 → 64x64)
# ✓ Processed: rock-557062.png (60x60 → 64x64)
# ✓ Processed: jeanne-darc-the-saint-431770.png (64x92 → 64x64)
# ✓ Processed: ghibli-redraw-927619.png (107x64 → 64x64)
# ✓ Processed: lilith-itou-530472.gif (64x64 → 64x64)
# ✓ Processed: notebook-236558.png (64x64 → 64x64)
# ✓ Processed: druid-843200.png (64x73 → 64x64)
# ✓ Processed: lightning-in-a-popsicle-274545.png (64x80 → 64x64)
# ✓ Processed: guide-953114.png (64x64 → 64x64)
# ✓ Processed: steampowered-292843.png (64x64 → 64x64)
# ✓ Processed: bill-cipher-207798.png (113x64 → 64x64)
# ✓ Processed: samus-dread-026416.png (38x51 → 64x64)
# ✓ Processed: island-postcard-407235.png (64x64 → 64x64)
# ✓ Processed: mobile-legends-sprite-031-moskov-533690.png (64x64 → 64x64)
# ✓ Processed: animated-potion-220524.gif (64x64 → 64x64)
# ✓ Processed: little-guys-big-problems-179962.png (64x64 → 64x64)
# ✓ Processed: vigil-398798.png (64x64 → 64x64)
# ✓ Processed: mr-jilk-554657.png (32x32 → 64x64)
# ⊗ Skipped: crossfoods-chinese-takeout-446272.gif (768x768 - exceeds 512x512 limit)
# ⊗ Skipped: crossfoods-foodtruck-053257.gif (768x768 - exceeds 512x512 limit)
# ✓ Processed: the-creeper-261929.png (64x85 → 64x64)
# ✓ Processed: transition-64-130698.gif (64x64 → 64x64)
# ✓ Processed: yes-409129.png (108x64 → 64x64)
# ⊗ Skipped: pixeljoint-class-photo-2025-collab-entry-261735.png (64x201, ratio: 0.32 - too tall)
# ✓ Processed: blocktales-epic-guise-greed-solitude-fear-hatred-983279.png (64x64 → 64x64)
# ✓ Processed: nuke-berry-rainblowd-ver-815492.png (64x73 → 64x64)
# ✓ Processed: burning-horizon-667521.png (68x64 → 64x64)
# ✓ Processed: jamallama-239732.png (64x64 → 64x64)
# ✓ Processed: sonic-in-mushroom-valley-995341.png (64x64 → 64x64)
# ✓ Processed: argentinian-singer-550737.png (64x64 → 64x64)
# ⊗ Skipped: dailyweapon-154076.gif (80x35, ratio: 2.29 - too wide)
# ✓ Processed: beep-beep-419719.png (64x64 → 64x64)
# ✓ Processed: machine-gun-400783.png (8x8 → 64x64)
# ⊗ Skipped: hot-woman-pixel-art-361311.png (288x96, ratio: 3.00 - too wide)
# ✓ Processed: card-558407.png (64x64 → 64x64)
# ✓ Processed: dragonborn-paladin-088514.png (64x67 → 64x64)
# ✓ Processed: lili-462972.png (64x88 → 64x64)
# ✓ Processed: topolobampo-sunrise-706345.png (85x64 → 64x64)
# ✓ Processed: jabberwocky-by-erutan-095466.png (48x48 → 64x64)
# ✓ Processed: the-road-not-taken-856788.png (64x64 → 64x64)
# ✓ Processed: palestine-tribute-424325.png (113x64 → 64x64)
# ⊗ Skipped: adventure-379666.png (64x32, ratio: 2.00 - too wide)
# ✓ Processed: globelifter-282630.png (64x64 → 64x64)
# ✓ Processed: hope-lost-in-a-dark-forest-793428.png (64x64 → 64x64)
# ✓ Processed: alchemy-906991.gif (78x64 → 64x64)
# ✓ Processed: neko-neko-236994.png (64x64 → 64x64)
# ✓ Processed: tomie-junji-ito-732592.png (64x64 → 64x64)
# ✓ Processed: color-revolution-836228.png (71x64 → 64x64)
# ✓ Processed: solshade-icon-928063.png (64x64 → 64x64)
# ✓ Processed: monocrome-dancing-475271.gif (64x64 → 64x64)
# ✓ Processed: treasure-daily-856895.png (64x64 → 64x64)
# ✓ Processed: wererabbit-903493.png (64x64 → 64x64)
# ✓ Processed: copper-scythe-2000-219182.png (64x96 → 64x64)
# ✓ Processed: ad-infinitum-754044.gif (64x64 → 64x64)
# ✓ Processed: froph-409972.png (64x64 → 64x64)
# ✓ Processed: captain-katsuragi-899748.png (64x64 → 64x64)
# ✓ Processed: archen-gif-609793.gif (64x64 → 64x64)
# ✓ Processed: space-vein-499902.png (64x64 → 64x64)
# ✓ Processed: hero-equipment-493493.png (71x64 → 64x64)
# ✓ Processed: losted-honor-718109.png (71x64 → 64x64)
# ✓ Processed: mega-man-zx-660864.png (66x64 → 64x64)
# ✓ Processed: tangled-headphones-462239.png (16x16 → 64x64)
# ✓ Processed: allure-803850.png (64x64 → 64x64)
# ✓ Processed: ibuki-162495.png (64x80 → 64x64)
# ⊗ Skipped: tetris-but-platformer-282895.png (316x166, ratio: 1.90 - too wide)
# ✓ Processed: leashothy-gnomeman-705099.png (64x80 → 64x64)
# ✓ Processed: archer-up-913583.png (16x16 → 64x64)
# ⊗ Skipped: rogue-racoon-372633.png (64x128, ratio: 0.50 - too tall)
# ✓ Processed: a-sinister-gate-049866.png (64x85 → 64x64)
# ✓ Processed: sleepy-little-guy-414426.png (32x32 → 64x64)
# ✓ Processed: sentinal-021977.png (64x64 → 64x64)
# ✓ Processed: paladin-355596.png (72x64 → 64x64)
# ✓ Processed: cute-outfit-911607.png (64x64 → 64x64)
# ✓ Processed: dark-soul-nes-857228.png (64x64 → 64x64)
# ✓ Processed: citlali-439440.png (64x64 → 64x64)
# ✓ Processed: swamp-1-3-284108.png (101x64 → 64x64)
# ⊗ Skipped: absrtacted-235278.png (2000x2000 - exceeds 512x512 limit)
# ✓ Processed: soldier-girl-preparation-610638.gif (112x64 → 64x64)
# ⊗ Skipped: noxus-the-entropic-god-942597.png (128x64, ratio: 2.00 - too wide)
# ✓ Processed: hero-the-gentle-healer-omori-fanart-215285.gif (64x64 → 64x64)
# ✓ Processed: minimap-008207.png (64x64 → 64x64)
# ✓ Processed: second-chance-825745.png (80x64 → 64x64)
# ✓ Processed: cheese-and-mouse-121666.png (32x32 → 64x64)
# ✓ Processed: wanted-did-you-see-her-316273.png (64x64 → 64x64)
# ✓ Processed: you-will-worship-god-357477.png (64x80 → 64x64)
# ✓ Processed: too-early-morning-355721.gif (64x64 → 64x64)
# ✓ Processed: itachi-908629.gif (64x64 → 64x64)
# ✓ Processed: najarala-674149.png (64x64 → 64x64)
# ✓ Processed: i-love-him-423852.png (64x64 → 64x64)
# ✓ Processed: tokyo-house-834133.png (64x64 → 64x64)
# ✓ Processed: ocean-986122.png (64x64 → 64x64)
# ⊗ Skipped: resistance-syrian-civil-war-208614.png (599x399 - exceeds 512x512 limit)
# ⊗ Skipped: touch-me-adam-115957.png (384x128, ratio: 3.00 - too wide)
# ✓ Processed: sonic-the-hedgehog-portrait-603907.png (64x64 → 64x64)
# ✓ Processed: textmode-lego-brickheadz-man-167526.png (64x64 → 64x64)
# ✓ Processed: island-daily-challenge-submission-214896.png (64x64 → 64x64)
# ✓ Processed: loon-bar-249072.png (64x64 → 64x64)
#
# Processing complete!
